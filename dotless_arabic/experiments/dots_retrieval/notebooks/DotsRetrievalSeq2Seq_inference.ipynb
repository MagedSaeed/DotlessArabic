# %% [markdown]
# # Installs

# %%
# !pip install -q tqdm
# !pip install -q seaborn
# !pip install -q datasets
# !pip install -q scikit-learn
# !pip install -q pytorch_lightning
# !pip install -q git+https://github.com/MagedSaeed/tkseem

# %% [markdown]
# # Prepare

# %%
import re
import os
import shutil
from pathlib import Path

from pyarabic import araby

from sklearn.model_selection import train_test_split

import numpy as np

import torch
from torch import nn
import torch.nn.functional as F
from torch.optim import Adam
from torch.utils.data import TensorDataset, DataLoader

import torchmetrics
from torchmetrics.functional import word_error_rate, char_error_rate

from pytorch_lightning import seed_everything
from pytorch_lightning.loggers import WandbLogger
from pytorch_lightning import LightningModule,Trainer
from pytorch_lightning.callbacks import EarlyStopping,LearningRateMonitor,ModelCheckpoint,RichProgressBar

from dotless_arabic.datasets.wikipedia.collect import collect_dataset_for_dots_retreival
from dotless_arabic import constants
from dotless_arabic.processing import undot,process

import datasets
import seaborn as sns
import matplotlib.pyplot as plt


import tkseem as tk
from tqdm.auto import tqdm

# %%
seed = 42

# %%
# random.seed(seed)     # python random generator
# np.random.seed(seed)  # numpy random generator

# torch.manual_seed(seed)
# torch.cuda.manual_seed_all(seed)

# torch.backends.cudnn.deterministic = True
# torch.backends.cudnn.benchmark = False

seed_everything(seed)
# Out:
# Global seed set to 42
# 42

# %%
tqdm.pandas()

# %% [markdown]
# # Load and explore the dataset

# %%
dataset = list(set(collect_dataset_for_dots_retreival()))
len(dataset)
# Out:
#   0%|          | 0/4636663 [00:00<?, ?it/s]
#   0%|          | 0/4636645 [00:00<?, ?it/s]
#   0%|          | 0/10867699 [00:00<?, ?it/s]
# 1440782

# %%
train_dataset,test_dataset = train_test_split(dataset,test_size=0.05,shuffle=True)
len(train_dataset),len(test_dataset)
# Out:
# (1368742, 72040)

# %% [markdown]
# trainset vocabulary and tokens count:

# %%
vocabs_dict = {}
for document in tqdm(train_dataset):
  for word in document.split():
    vocabs_dict[word] = vocabs_dict.get(word,0)+1
f'{len(vocabs_dict.keys()):,}',f'{sum(vocabs_dict.values()):,}'
# Out:
#   0%|          | 0/1368742 [00:00<?, ?it/s]
# ('2,552,981', '61,515,015')

# %% [markdown]
# # Clean and Preprocess the dataset

# %%
# text cleaning

def rm_link(text):
    return re.sub(r'https?://\S+|www\.\S+', '', text)

# handle case like "shut up okay?Im only 10 years old"
# become "shut up okay Im only 10 years old"
def rm_punct2(text):
    return re.sub(r'[\!\"\#\$\%\&\'\(\)\*\+\,\-\.\/\:\;\<\=\>\?\@\[\\\]\^\_\`\{\|\}\~]', ' ', text)
    # return re.sub(r'[\"\#\$\%\&\'\(\)\*\+\/\:\;\<\=\>\@\[\\\]\^\_\`\{\|\}\~]', ' ', text)
    # return text.translate(str.maketrans('', '', string.punctuation))

def rm_html(text):
    return re.sub(r'<[^>]+>', '', text)

def space_bt_punct(text):
    pattern = r'([.,!?-])'
    s = re.sub(pattern, r' \1 ', text)     # add whitespaces between punctuation
    s = re.sub(r'\s{2,}', ' ', s)        # remove double whitespaces
    return s

def rm_number(text):
    return re.sub(r'\d+', '', text)

def rm_extra_whitespaces(text):
    return re.sub(r' +', ' ', text)

# def rm_nonascii(text):
#     return re.sub(r'[^\x00-\x7f]', r'', text)

def rm_emoji(text):
    emojis = re.compile(
        '['
        u'\U0001F600-\U0001F64F'  # emoticons
        u'\U0001F300-\U0001F5FF'  # symbols & pictographs
        u'\U0001F680-\U0001F6FF'  # transport & map symbols
        u'\U0001F1E0-\U0001F1FF'  # flags (iOS)
        u'\U00002702-\U000027B0'
        u'\U000024C2-\U0001F251'
        ']+',
        flags=re.UNICODE
    )
    return emojis.sub(r'', text)

# def spell_correction(text):
#     return re.sub(r'(.)\1+', r'\1\1', text)

def clean_pipeline(text):
    text = rm_link(text)
    text = rm_html(text)
    text = space_bt_punct(text)
    # text = rm_punct2(text)
    text = rm_number(text)
    # text = rm_nonascii(text)
    text = rm_emoji(text)
    """arabic specific"""
    text = araby.strip_diacritics(text)
    text = araby.strip_tatweel(text)
    text = araby.normalize_alef(text)
    text = araby.normalize_hamza(text)
    text = araby.normalize_ligature(text)
    # remove any non arabic character
    text = "".join(
        [c for c in text if c in constants.ARABIC_LETTERS or c.isspace()]
    )
    text = rm_extra_whitespaces(text)
    # text = spell_correction(text)
    return process(text).strip()

# %%
clean_pipeline('السلام عليكم ورحمة. الله')
# Out:
# 'السلام عليكم ورحمة الله'

# %%
def prepare(text):
  return clean_pipeline(text)

# %%
# test the prepare method
prepare('hello بالإنجليزية تعني أهلاً')
# Out:
# 'بالانجليزية تعني اهلا'

# %%
train_dataset = list(map(prepare,tqdm(train_dataset)))
train_dataset = list(filter(lambda doc:len(doc)>0,tqdm(train_dataset)))
train_dataset[:2]
# Out:
#   0%|          | 0/1368742 [00:00<?, ?it/s]
#   0%|          | 0/1368742 [00:00<?, ?it/s]
# ['عاش مواطنو كوريا الجنوبية تحت انظمة حكم غير ديموقراطية معظم القرن العشرين وهي انظمة شمولية عسكرية لزعماء امثال اي سنغ مان وباك تشونغ هي وتشون دو هوان وروو تاي وو',
#  'وعندما دخل السفير الاسراءيلي الياهو بن اليسار الا قاعة العرش وقدم اوراق اعتماده سفيرا فوق العادة ومطلق الصلاحية الا الملك محمد انور بن فاروق بن فءاد بن السادات توقفنا عن اذاعة القران الكريم ونصبنا الصلوات وبدانا نستقبل المعزين']

# %%
test_dataset = list(map(prepare,tqdm(test_dataset)))
test_dataset = list(filter(lambda doc:len(doc)>0,tqdm(test_dataset)))
test_dataset[:2]
# Out:
#   0%|          | 0/72040 [00:00<?, ?it/s]
#   0%|          | 0/72040 [00:00<?, ?it/s]
# ['في حزيران غادر ليون بلوم منصبه وعاد ادوار دالادير الا الحكم رافعا شعار التمسك بالامبراطورية الفرنسية فسافر الرءيس جميل مردم بك الا باريس في تشرين الثاني ووقع عدة ملاحق للمعاهدة السورية الفرنسية فيها الكثير من التنازلات منها ضمانات اضافية للاقليات والتاكيد علا الاستعانة بخبراء فرنسيين داءمين في مءسسات الحكم السورية',
#  'يعتبر الحكم سعد العقيل من الحكام السابقين في التحكيم ولقد عاصر كثيرا من الحكام مثل الحكم عمر المهنا وعبد الله الناصر وفلاج الشنار والشريف وعبد الرحمن الدهام وفهد الدهمش وكثير من الحكام ولكن ظلم هذا الحكم من الاعلام ويعتبر من اشهر الحكام في منطقة الاحساء علا زمان الحكم حسين الحساوي وسعد ربيعة']

# %%
vocabs_dict = {}
for document in tqdm(train_dataset):
  for word in document.split():
    vocabs_dict[word] = vocabs_dict.get(word,0)+1
f'{len(vocabs_dict.keys()):,}',f'{sum(vocabs_dict.values()):,}'
# Out:
#   0%|          | 0/1368224 [00:00<?, ?it/s]
# ('1,040,339', '59,208,516')

# %% [markdown]
# # Helper functions and constants

# %%
train_dataset[0]
# Out:
# 'عاش مواطنو كوريا الجنوبية تحت انظمة حكم غير ديموقراطية معظم القرن العشرين وهي انظمة شمولية عسكرية لزعماء امثال اي سنغ مان وباك تشونغ هي وتشون دو هوان وروو تاي وو'

# %%
# Find out the max samples token
# sorted_docs_by_length = sorted(tqdm(train_dataset),key=lambda document: len(document.split()),reverse=True)
sorted_docs_by_length = sorted(tqdm(train_dataset),key=len,reverse=True)
len(sorted_docs_by_length[0]),\
len(sorted_docs_by_length[1]),\
len(sorted_docs_by_length[2]),\
len(sorted_docs_by_length[5]),\
len(sorted_docs_by_length[10]),\
len(sorted_docs_by_length[50]),\
len(sorted_docs_by_length[1_000]),\
len(sorted_docs_by_length[2_500]),\
len(sorted_docs_by_length[5_000]),\
len(sorted_docs_by_length[10_000])
# Out:
#   0%|          | 0/1368224 [00:00<?, ?it/s]
# (8115, 7783, 7723, 6226, 4763, 2955, 1431, 1127, 940, 786)

# %%
# Find out the max samples token
# sorted_docs_by_length = sorted(tqdm(test_dataset),key=lambda document: len(document.split()),reverse=True)
sorted_docs_by_length = sorted(tqdm(test_dataset),key=len,reverse=True)
len(sorted_docs_by_length[0]),\
len(sorted_docs_by_length[1]),\
len(sorted_docs_by_length[2]),\
len(sorted_docs_by_length[5]),\
len(sorted_docs_by_length[10]),\
len(sorted_docs_by_length[50]),\
len(sorted_docs_by_length[1_000]),\
len(sorted_docs_by_length[2_500]),\
len(sorted_docs_by_length[5_000]),\
len(sorted_docs_by_length[10_000])
# Out:
#   0%|          | 0/72025 [00:00<?, ?it/s]
# (3542, 3070, 3065, 2613, 2338, 1489, 661, 511, 412, 332)

# %%
# setting seq_len:
seq_len = 500

# %%
def create_features_from_text_list(text_list,tokenizer):
  encoded = list()
  for doc in tqdm(text_list):
    encoded_doc = tokenizer.encode(doc)
    encoded_doc = tokenizer.pad(encoded_doc,length=seq_len)
    encoded_doc = encoded_doc[:seq_len]
    encoded.append(np.array(encoded_doc))
  return np.array(encoded)

# %%
# define batch size
batch_size = 128

# %%
def calculate_text_metrics(predictions,labels,target_tokenizer, print_text=False):
  # drop pads, those pads are not necessary pad tokens!!
  last_pad = predictions[-1]
  for i,pad in reversed(list(enumerate(predictions))):
    if pad == last_pad:
      predictions.pop(i)
    else:
      break

  predicted_text = target_tokenizer.detokenize(target_tokenizer.decode(predictions))
  predicted_text = predicted_text.replace('<PAD>','').strip()

  true_text = target_tokenizer.detokenize(target_tokenizer.decode(labels))
  true_text = true_text.replace('<PAD>','').strip()

  if print_text:
    print('*'*100)
    print(predicted_text)
    print(true_text)

  wer = word_error_rate(preds=predicted_text, target=true_text)
  cer = char_error_rate(preds=predicted_text, target=true_text)
  return wer,cer,predicted_text,true_text

# %% [markdown]
# # Add masked consontants column to the dataset

# %%
undotted_train_dataset = list(map(undot,tqdm(train_dataset)))
undotted_train_dataset[:2]
# Out:
#   0%|          | 0/1368224 [00:00<?, ?it/s]
# ['عاس مواطٮو كورٮا الحٮوٮٮه ٮحٮ اٮطمه حكم عٮر دٮموڡراطٮه معطم الڡرں العسرٮں وهى اٮطمه سمولٮه عسكرٮه لرعماء امٮال اى سٮع ماں وٮاك ٮسوٮع هى وٮسوں دو هواں وروو ٮاى وو',
#  'وعٮدما دحل السڡٮر الاسراءٮلى الٮاهو ٮں الٮسار الا ڡاعه العرس وڡدم اوراٯ اعٮماده سڡٮرا ڡوٯ العاده ومطلٯ الصلاحٮه الا الملك محمد اٮور ٮں ڡاروٯ ٮں ڡءاد ٮں الساداٮ ٮوڡڡٮا عں اداعه الڡراں الكرٮم وٮصٮٮا الصلواٮ وٮداٮا ٮسٮڡٮل المعرٮں']

# %%
undotted_test_dataset = list(map(undot,tqdm(test_dataset)))
undotted_test_dataset[:2]
# Out:
#   0%|          | 0/72025 [00:00<?, ?it/s]
# ['ڡى حرٮراں عادر لٮوں ٮلوم مٮصٮه وعاد ادوار دالادٮر الا الحكم راڡعا سعار الٮمسك ٮالامٮراطورٮه الڡرٮسٮه ڡساڡر الرءٮس حمٮل مردم ٮك الا ٮارٮس ڡى ٮسرٮں الٮاٮى ووڡع عده ملاحٯ للمعاهده السورٮه الڡرٮسٮه ڡٮها الكٮٮر مں الٮٮارلاٮ مٮها صماٮاٮ اصاڡٮه للاڡلٮاٮ والٮاكٮد علا الاسٮعاٮه ٮحٮراء ڡرٮسٮٮں داءمٮں ڡى مءسساٮ الحكم السورٮه',
#  'ٮعٮٮر الحكم سعد العڡٮل مں الحكام الساٮڡٮں ڡى الٮحكٮم ولڡد عاصر كٮٮرا مں الحكام مٮل الحكم عمر المهٮا وعٮد الله الٮاصر وڡلاح السٮار والسرٮڡ وعٮد الرحمں الدهام وڡهد الدهمس وكٮٮر مں الحكام ولكں طلم هدا الحكم مں الاعلام وٮعٮٮر مں اسهر الحكام ڡى مٮطڡه الاحساء علا رماں الحكم حسٮں الحساوى وسعد رٮٮعه']

# %% [markdown]
# # Build the BiLSTM Model

# %%
# model architecture (with some amends)
# https://www.kaggle.com/code/affand20/imdb-with-pytorch

class LitBiLSTMModel(LightningModule):
    def __init__(
        self,
        vocab_size,
        output_size,
        pad_id=1, # the default value from tkseem tokenizers
        seq_len=seq_len,
        hidden_size=512,
        embedding_size=512,
        embedding_dropout=0.25,
        dropout=0.33,
        learning_rate=0.001,
        n_layers=2,
        bidirectional=True,
      ):
        super().__init__()

        self.save_hyperparameters()

        self.bidirectional = bidirectional
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.dropout_prop = dropout
        self.pad_id = pad_id
        self.max_sequence_length = seq_len
        self.output_size = output_size

        self.train_accuracy = torchmetrics.Accuracy(
            task="multiclass",
            num_classes=output_size,
            ignore_index=self.pad_id,
          )
        self.val_accuracy = torchmetrics.Accuracy(
            task="multiclass",
            num_classes=output_size,
            ignore_index=self.pad_id,
          )
        self.test_accuracy = torchmetrics.Accuracy(
            task="multiclass",
            num_classes=output_size,
            ignore_index=self.pad_id,
          )

        # embedding layer is useful to map input into vector representation
        self.embedding = nn.Embedding(vocab_size, embedding_size)

        # LSTM layer preserved by PyTorch library
        self.lstm = nn.LSTM(
              embedding_size,
              hidden_size,
              n_layers,
              dropout=dropout,
              batch_first=True,
              bidirectional=bidirectional,
        )

        # dropout layer
        self.dropout = nn.Dropout(dropout)
        self.embedding_dropout = nn.Dropout(embedding_dropout)

        # Linear layer for output
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, inputs):
        outputs = self.embedding(inputs)
        outputs = self.embedding_dropout(outputs) # apply dropout on embedding
        inputs_lengths = torch.sum(inputs!=self.pad_id,axis=-1).cpu()
        packed_outputs = nn.utils.rnn.pack_padded_sequence(
            outputs,
            inputs_lengths,
            batch_first=True,
            enforce_sorted=False,
          )
        if not self.bidirectional:
          # pass forward to lstm
          packed_outputs, _ =  self.lstm(packed_outputs)
          outputs,lengths = nn.utils.rnn.pad_packed_sequence(
              packed_outputs,
              batch_first=True,
              total_length=self.max_sequence_length,
            )
        else:
          bidirectional_packed_outputs,_ = self.lstm(packed_outputs)
          bidirectional_outputs,lengths = nn.utils.rnn.pad_packed_sequence(
              bidirectional_packed_outputs,
              batch_first=True,
              # padding_value=self.pad_id,
              total_length=self.max_sequence_length,
            )
          outputs = bidirectional_outputs[:, :, : self.hidden_size] + bidirectional_outputs[:, :, self.hidden_size :]
        outputs = self.dropout(outputs)
        outputs = self.fc(outputs)
        # softmax will be done in the loss calculation
        return outputs

    def step(self, inputs, labels):
        assert torch.sum(inputs==self.pad_id)==torch.sum(labels==self.pad_id),\
             f'pad ids and their target tags does not match: {torch.sum(inputs==self.pad_id):=} != {torch.sum(labels==self.pad_id):=}'
        outputs = self(inputs)
        outputs = outputs.squeeze()
        outputs = outputs.view(outputs.shape[0]*outputs.shape[1],-1)
        labels = labels.view(-1)
        return outputs,labels

    def training_step(self, batch, batch_idx):
        inputs, labels = batch
        outputs,labels = self.step(inputs, labels)
        loss = F.cross_entropy(
            outputs,
            labels,
            ignore_index=self.pad_id,
          )
        train_accuracy = self.train_accuracy(outputs, labels)
        self.log(
            "loss",
            loss,
            prog_bar=True,
            on_step=True,
            on_epoch=False,
        )
        self.log(
            "train_acc",
            train_accuracy,
            on_step=True,
            on_epoch=False,
            prog_bar=True,
            logger=True,
        )
        return loss

    def validation_step(self, batch, batch_idx):
        inputs, labels = batch
        outputs,labels = self.step(inputs, labels)
        loss = F.cross_entropy(
            outputs,
            labels,
            ignore_index=self.pad_id,
          )
        val_accuracy = self.val_accuracy(outputs, labels)
        self.log("val_loss", loss, prog_bar=True)
        self.log(
            "val_acc",
            val_accuracy,
            on_step=True,
            on_epoch=False,
            prog_bar=True,
            logger=True,
        )
        return {"val_loss": loss}

    def test_step(self, batch, batch_idx):
        inputs, labels = batch
        outputs,labels = self.step(inputs, labels)
        loss = F.cross_entropy(
            outputs,
            labels,
            ignore_index=self.pad_id,
          )
        test_accuracy = self.test_accuracy(outputs,labels)
        metrics = {"test_acc": test_accuracy, "test_loss": loss}
        self.log_dict(metrics, prog_bar=True)
        return outputs

    def predict_step(self, batch, batch_idx):
      inputs,labels = batch
      outputs,labels = self.step(inputs,labels)
      predictions = torch.argmax(outputs,dim=-1)
      return predictions,labels

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(
            self.parameters(),
            lr=self.learning_rate,
        )
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer=optimizer,
            factor=0.5,
            patience=1,
            verbose=True,
        )
        return {
            "optimizer": optimizer,
            "lr_scheduler": scheduler,
            "monitor": "val_loss",
        }

# %%
def train_model(
    model,
    train_dataloader,
    val_dataloader,
    text_type,
    max_epochs=50,
    validate_and_fit=False
  ):
  checkpoints_path = Path(f"./DotsRetrieval/{text_type}")
  if validate_and_fit:
    shutil.rmtree(checkpoints_path, ignore_errors=True)
  checkpoint_callback = ModelCheckpoint(
      mode="min",
      save_top_k=1,
      verbose=False,
      save_last=True,
      monitor="val_loss",
      save_weights_only=False,
      auto_insert_metric_name=True,
      save_on_train_epoch_end=False,
      dirpath=f"{checkpoints_path}/checkpoints",
      filename="{epoch}-{val_loss:.3f}-{step}",
  )
  callbacks = list()
  callbacks.append(checkpoint_callback)
  early_stopping_callback = EarlyStopping(
      monitor="val_loss",
      # min_delta=0.025,
      min_delta=0,
      patience=10,
      check_finite=True,
  )
  callbacks.append(early_stopping_callback)
  lr_monitor = LearningRateMonitor(
      logging_interval="step",
      log_momentum=True,
  )
  callbacks.append(lr_monitor)
#   callbacks.append(RichProgressBar())
  devices = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
  trainer = Trainer(
      deterministic=True,
      callbacks=callbacks,
      gradient_clip_val=5,
      fast_dev_run=False,
      max_epochs=max_epochs,
      val_check_interval=0.25,
      accelerator="auto",
      devices=[1],
      # log_every_n_steps=max(len(train_dataloader) // 25, 1),
      log_every_n_steps=max(len(train_dataloader) // 25, 1),
  )
  if validate_and_fit:
    trainer.validate(
        model=model,
        dataloaders=val_dataloader,
    )
    trainer.fit(
        model,
        train_dataloader,
        val_dataloader,
  )
  return trainer

# %% [markdown]
# # Prepare vocab

# %% [markdown]
# ## source tokenizer

# %%
source_tokenizer = tk.CharacterTokenizer(vocab_size=10_000_000)

# %%
source_tokenizer.train(text='\n'.join(undotted_train_dataset))
# Out:
# Training CharacterTokenizer ...

# %%
source_tokenizer.vocab_size
# Out:
# 40

# %%
# test the tokenizer
source_tokenizer.tokenize(undot('السلام عليكم و رحمة الله و بركاته')),source_tokenizer.encode(undot('السلام عليكم و رحمة الله و بركاته'))
# Out:
# (['ا',
#   '##ل',
#   '##س',
#   '##ل',
#   '##ا',
#   '##م',
#   'ع',
#   '##ل',
#   '##ٮ',
#   '##ك',
#   '##م',
#   'و',
#   'ر',
#   '##ح',
#   '##م',
#   '##ه',
#   'ا',
#   '##ل',
#   '##ل',
#   '##ه',
#   'و',
#   'ٮ',
#   '##ر',
#   '##ك',
#   '##ا',
#   '##ٮ',
#   '##ه'],
#  [5,
#   4,
#   13,
#   4,
#   3,
#   8,
#   23,
#   4,
#   2,
#   21,
#   8,
#   18,
#   33,
#   11,
#   8,
#   6,
#   5,
#   4,
#   4,
#   6,
#   18,
#   12,
#   7,
#   21,
#   3,
#   2,
#   6])

# %% [markdown]
# ## target tokenizer

# %%
target_tokenizer = tk.CharacterTokenizer(vocab_size=10_000_000)

# %%
target_tokenizer.train(text='\n'.join(train_dataset))
# Out:
# Training CharacterTokenizer ...

# %%
target_tokenizer.vocab_size
# Out:
# 62

# %%
# test the tokenizer
target_tokenizer.tokenize('السلام عليكم و رحمة الله و بركاته'),target_tokenizer.encode('السلام عليكم و رحمة الله و بركاته')
# Out:
# (['ا',
#   '##ل',
#   '##س',
#   '##ل',
#   '##ا',
#   '##م',
#   'ع',
#   '##ل',
#   '##ي',
#   '##ك',
#   '##م',
#   'و',
#   'ر',
#   '##ح',
#   '##م',
#   '##ة',
#   'ا',
#   '##ل',
#   '##ل',
#   '##ه',
#   'و',
#   'ب',
#   '##ر',
#   '##ك',
#   '##ا',
#   '##ت',
#   '##ه'],
#  [5,
#   3,
#   15,
#   3,
#   2,
#   7,
#   26,
#   3,
#   4,
#   20,
#   7,
#   16,
#   49,
#   22,
#   7,
#   11,
#   5,
#   3,
#   3,
#   18,
#   16,
#   24,
#   8,
#   20,
#   2,
#   9,
#   18])

# %%
target_tokenizer.detokenize(target_tokenizer.tokenize('السلام عليكم و رحمة الله و بركاته'))
# Out:
# 'السلام عليكم و رحمة الله و بركاته'

# %% [markdown]
# # Run the experiment

# %% [markdown]
# ## tokenize and split

# %%
encoded_trainset = create_features_from_text_list(text_list=undotted_train_dataset,tokenizer=source_tokenizer)
trainy = create_features_from_text_list(text_list=train_dataset,tokenizer=target_tokenizer)
# Out:
#   0%|          | 0/1368224 [00:00<?, ?it/s]
#   0%|          | 0/1368224 [00:00<?, ?it/s]

# %%
encoded_testset = create_features_from_text_list(text_list=undotted_test_dataset,tokenizer=source_tokenizer)
testy = create_features_from_text_list(text_list=test_dataset,tokenizer=target_tokenizer)
# Out:
#   0%|          | 0/72025 [00:00<?, ?it/s]
#   0%|          | 0/72025 [00:00<?, ?it/s]

# %%
testy_with_dots = create_features_from_text_list(text_list=test_dataset,tokenizer=target_tokenizer)
# Out:
#   0%|          | 0/72025 [00:00<?, ?it/s]

# %%
encoded_trainset, encoded_valset, trainy, valy = train_test_split(
  encoded_trainset,
  trainy,
  test_size=0.1,
  random_state=seed,
)
len(encoded_trainset),len(encoded_valset),len(trainy), len(valy)
# Out:
# (1231401, 136823, 1231401, 136823)

# %%
encoded_trainset.shape,trainy.shape
# Out:
# ((1231401, 500), (1231401, 500))

# %%
# create tensor datasets
trainset = TensorDataset(torch.from_numpy(encoded_trainset), torch.from_numpy(trainy))
validset = TensorDataset(torch.from_numpy(encoded_valset), torch.from_numpy(valy))
testset = TensorDataset(torch.from_numpy(encoded_testset), torch.from_numpy(testy))
testset_with_dots = TensorDataset(torch.from_numpy(encoded_testset), torch.from_numpy(testy_with_dots))

# %%
# create dataloaders
trainloader = DataLoader(trainset, shuffle=True, batch_size=batch_size,num_workers=4)
valloader = DataLoader(validset, shuffle=False, batch_size=batch_size,num_workers=4,drop_last=False)
testloader = DataLoader(testset, shuffle=False, batch_size=batch_size,num_workers=4,drop_last=False)
testloader_with_dots = DataLoader(testset_with_dots,shuffle=False,batch_size=batch_size,num_workers=4,drop_last=False)

# %% [markdown]
# ## build and train the model

# %%
model = LitBiLSTMModel(
    vocab_size=source_tokenizer.vocab_size,
    output_size=target_tokenizer.vocab_size,
  )
model
# Out:
# LitBiLSTMModel(
#   (train_accuracy): MulticlassAccuracy()
#   (val_accuracy): MulticlassAccuracy()
#   (test_accuracy): MulticlassAccuracy()
#   (embedding): Embedding(40, 512)
#   (lstm): LSTM(512, 512, num_layers=2, batch_first=True, dropout=0.33, bidirectional=True)
#   (dropout): Dropout(p=0.33, inplace=False)
#   (embedding_dropout): Dropout(p=0.25, inplace=False)
#   (fc): Linear(in_features=512, out_features=62, bias=True)
# )

# %%
trainer = train_model(
    model,
    train_dataloader=trainloader,
    val_dataloader=valloader,
    text_type='dotless-to-dotted',
  )
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %%
trainer.test(
    model=model,
    ckpt_path='./DotsRetrieval/dotless-to-dotted/checkpoints/epoch=49-val_loss=0.030-step=279625.ckpt',
    dataloaders=testloader,
)
# Out:
# You are using a CUDA device ('NVIDIA RTX A4500') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# Restoring states from the checkpoint path at ./DotsRetrieval/dotless-to-dotted/checkpoints/epoch=49-val_loss=0.030-step=279625.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Loaded model weights from the checkpoint at ./DotsRetrieval/dotless-to-dotted/checkpoints/epoch=49-val_loss=0.030-step=279625.ckpt
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.9916979670524597     │
# │         test_loss         │   0.024777263402938843    │
# └───────────────────────────┴───────────────────────────┘
# [{'test_acc': 0.9916979670524597, 'test_loss': 0.024777263402938843}]

# %% [markdown]
# find the text metrics, (wer,cer,ver)

# %%
model_predictions = trainer.predict(
    model=model,
    dataloaders=testloader,
    ckpt_path='./DotsRetrieval/dotless-to-dotted/checkpoints/epoch=49-val_loss=0.030-step=279625.ckpt',
)
# Out:
# Restoring states from the checkpoint path at ./DotsRetrieval/dotless-to-dotted/checkpoints/epoch=49-val_loss=0.030-step=279625.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Loaded model weights from the checkpoint at ./DotsRetrieval/dotless-to-dotted/checkpoints/epoch=49-val_loss=0.030-step=279625.ckpt
# Predicting: 0it [00:00, ?it/s]

# %%
predictions = list()
labels = list()
for (batch_predictions,batch_labels) in model_predictions:
  batch_predictions = batch_predictions.view(-1,seq_len)
  batch_labels = batch_labels.view(-1,seq_len)
  for sample_predictions,sample_labels in zip(batch_predictions,batch_labels):
    predictions.append(sample_predictions)
    labels.append(sample_labels)
print('len predictions and lables of the test set:',len(predictions),len(labels))
# Out:
# len predictions and lables of the test set: 72025 72025

# %%
wers,cers,vers = list(),list(),list()
for sample_preds,sample_labels in tqdm(zip(predictions[:100],labels[:100]),total=len(predictions)):
  wer,cer,p,t = calculate_text_metrics(
      predictions=sample_preds.tolist(),
      labels=sample_labels.tolist(),
      target_tokenizer=target_tokenizer,
      print_text=True,
    )
  wers.append(wer)
  cers.append(cer)
# Out:
#   0%|          | 0/72025 [00:00<?, ?it/s]
# ****************************************************************************************************
# في حزيران غادر ليون بلوم منصبه وعاد ادوار دالادير الا الحكم رافعا شعار التمسك بالامبراطورية الفرنسية فسافر الرءيس جميل مردم بك الا باريس في تشرين الثاني ووقع عدة ملاحق للمعاهدة السورية الفرنسية فيها الكثير من التنازلات منها ضمانات اضافية للاقليات والتاكيد علا الاستعانة بخبراء فرنسيين داءمين في مءسسات الحكم السورية
# في حزيران غادر ليون بلوم منصبه وعاد ادوار دالادير الا الحكم رافعا شعار التمسك بالامبراطورية الفرنسية فسافر الرءيس جميل مردم بك الا باريس في تشرين الثاني ووقع عدة ملاحق للمعاهدة السورية الفرنسية فيها الكثير من التنازلات منها ضمانات اضافية للاقليات والتاكيد علا الاستعانة بخبراء فرنسيين داءمين في مءسسات الحكم السورية
# ****************************************************************************************************
# يعتبر الحكم سعد العقيل من الحكام السابقين في التحكيم ولقد عاصر كثيرا من الحكام مثل الحكم عمر المهنا وعبد الله الناصر وفلاح الستار والشريف وعبد الرحمن الدهام وفهد الدهمش وكثير من الحكام ولكن ظلم هذا الحكم من الاعلام ويعتبر من اشهر الحكام في منطقة الاحساء علا زمان الحكم حسين الحساوي وسعد ربيعة
# يعتبر الحكم سعد العقيل من الحكام السابقين في التحكيم ولقد عاصر كثيرا من الحكام مثل الحكم عمر المهنا وعبد الله الناصر وفلاج الشنار والشريف وعبد الرحمن الدهام وفهد الدهمش وكثير من الحكام ولكن ظلم هذا الحكم من الاعلام ويعتبر من اشهر الحكام في منطقة الاحساء علا زمان الحكم حسين الحساوي وسعد ربيعة
# ****************************************************************************************************
# في احد المرات فاز رحمان خان بمباراة البرد امام الملك فقفز فرحا وصفق بكوعيه مما اغضب الملك ساولو فتحدا رجولة رحمن خان ان استطاع ان يتمرد عليه ومعه مقاطعته ياغو
# في احد المرات فاز رحمان خان بمباراة النرد امام الملك فقفز فرحا وصفق بكوعيه مما اغضب الملك ساولو فتحدا رجولة رحمن خان ان استطاع ان يتمرد عليه ومعه مقاطعته باغو
# ****************************************************************************************************
# في بداية القرن الماضي توصل العلماء يءكد ان الانسان منذ ولادته تمر حياته في ثلاث دورات متكررة تتعلق احدا هذه الدورات بحالته الجسدية او البدنية وتتعلق الثانية بحياته العاطفية او الحسية اما الدورة الثالثة فهي دورة نشاطه العقلي او الذهني
# في بداية القرن الماضي توصل العلماء تءكد ان الانسان منذ ولادته تمر حياته في ثلاث دورات متكررة تتعلق احدا هذه الدورات بحالته الجسدية او البدنية وتتعلق الثانية بحياته العاطفية او الحسية اما الدورة الثالثة فهي دورة نشاطه العقلي او الذهني
# ****************************************************************************************************
# اما في السور الاخرا فقد استعمل النسور بمعناه اللغوي اي الارتفاع والعلو الحسي فقوله تعالا وانظر الا العظام كيف ينشرها اي كيف ترفعها او ترفع بعضها علا بعض في التركيب اي يركب بعضها فوق بعض لاحياءها وقوله عز وجل واذا قيل ابشروا فابشروا فهو بمعنا القيام من المجلس اي الارتفاع عنه
# اما في السور الاخرا فقد استعمل النشوز بمعناه اللغوي اي الارتفاع والعلو الحسي فقوله تعالا وانظر الا العظام كيف ننشزها اي كيف نرفعها او نرفع بعضها علا بعض في التركيب اي نركب بعضها فوق بعض لاحياءها وقوله عز وجل واذا قيل انشزوا فانشزوا فهو بمعنا القيام من المجلس اي الارتفاع عنه
# ****************************************************************************************************
# كان طلال تلميذا في احد مدارس مدينة الطاءف بالسعودية وكانت هذه المدرسة تقيم عدة حفلات في مناسبات عدة وكان معروفا عن ظلال حلاوة الصوت وتفاوته الامر الذي شجع المدرسة علا ان يسند اليه القيام بمقرء الحفل في كل حفلات المدرسة
# كان طلال تلميذا في احد مدارس مدينة الطاءف بالسعودية وكانت هذه المدرسة تقيم عدة حفلات في مناسبات عدة وكان معروفا عن طلال حلاوة الصوت ونقاوته الامر الذي شجع المدرسة علا ان تسند اليه القيام بمقرء الحفل في كل حفلات المدرسة
# ****************************************************************************************************
# في مايو رفع دعوا قضاءية ضد فير كلان ادعا انه اجبر علا العيش في احد منازلهم في لوس انجلوس واجبرعلا تناول المشروبات الكحولية دون السن القانونية والقمار بشكل غير قانوني واخذ امواله التي يجنيها من تويتش ويوتيوب
# في مايو رفع دعوا قضاءية ضد فيز كلان ادعا انه اجبر علا العيش في احد منازلهم في لوس انجلوس واجبرعلا تناول المشروبات الكحولية دون السن القانونية والقمار بشكل غير قانوني واخذ امواله التي يجنيها من تويتش ويوتيوب
# ****************************************************************************************************
# ومن الانظمة المستخدمة في وقتنا الحالي لتوصيل الدواء كل من ديدرايمز المبلمرات والجسيمات الشخمسة ليبوسومات الا ان الانابيب النانوية الكربونية وفرت الفرصة للعمل مع الهياكل الفعالة والتي لها امكانيات تحميل عالية للدواء وسمات احتراق للخلية
# ومن الانظمة المستخدمة في وقتنا الحالي لتوصيل الدواء كل من دندرايمر المبلمرات والجسيمات الشحمسة ليبوسومات الا ان الانابيب النانوية الكربونية وفرت الفرصة للعمل مع الهياكل الفعالة والتي لها امكانيات تحميل عالية للدواء وسمات اختراق للخلية
# ****************************************************************************************************
# كما تاثرالشيخ احمد عيسا عاشور عام بالامام الشيخ محمود خطاب السبكي مءسس الجمعية الشرعية وبفكره الاسلامي السلفي بمكاتب علاقته وثيقة بالامام الثاني للجمعية الاستاذ امين محمود خطاب وبخاصة بعد ان اصدر مجلته الاعتصام في عام فانضم الا كتيبة العاملين بمجلة الجمعية الشرعية ثم اختير بالاجماع وكيلا لمجلس ادارة الجمعية الشرعية وكلف رسميا بالقيام علا شءون الفتوا فيها وفي عام اختاره مجلس ادارة الجمعية الشرعية بالاجماع ليكون رءيسا لبعثة الحج التي كانت الجمعية تبعتها كل عام
# كما تاثرالشيخ احمد عيسا عاشور عام بالامام الشيخ محمود خطاب السبكي مءسس الجمعية الشرعية وبفكره الاسلامي السلفي ثمكانت علاقته وثيقة بالامام الثاني للجمعية الاستاذ امين محمود خطاب وبخاصة بعد ان اصدر مجلته الاعتصام في عام فانضم الا كتيبة العاملين بمجلة الجمعية الشرعية ثم اختير بالاجماع وكيلا لمجلس ادارة الجمعية الشرعية وكلف رسميا بالقيام علا شءون الفتوا فيها وفي عام اختاره مجلس ادارة الجمعية الشرعية بالاجماع ليكون رءيسا لبعثة الحج التي كانت الجمعية تبعثها كل عام
# ****************************************************************************************************
# قال بيتر ماندافيل الاستاذ بجامعة جورج ماسون والمستشار السابق لوزارة الخارجية الامريكية حول الاسلام السياسي ان وفاة مرسي تجاوز صداها جماعة الاخوان المسلمين الا المصريين الاخرين الذين صوتوا لصالحه او لديهم مخاوف بشان سجل الحكومة الحالي في ملف حقوق الانسان
# قال بيتر ماندافيل الاستاذ بجامعة جورج ماسون والمستشار السابق لوزارة الخارجية الامريكية حول الاسلام السياسي ان وفاة مرسي تجاوز صداها جماعة الاخوان المسلمين الا المصريين الاخرين الذين صوتوا لصالحه او لديهم مخاوف بشان سجل الحكومة الحالي في ملف حقوق الانسان
# ****************************************************************************************************
# فبعد ان هاجر العتوب من نجد في القرن السابع عشر استقروا في قطر التي كانت تحت حكم ال مسلم وهناك اكتسب العتوب مهارات الصيد والغوص علا اللءلء مكتسبين خبراتهم البحرية من المناطق المحيطة بهم كعمان والبحرين الا ان استقرارهم في قطر لم يطل نتيجة لخلاف بين العتوب و ال مسلم فهاجر بعض العتوب بعد ذلك الا البحرين فيما استقر ما يقارب من سفينة عند مدخل شط العرب حيث اجبرته السلطات العثمانية علا الرحيل فسكنوا القرين
# فبعد ان هاجر العتوب من نجد في القرن السابع عشر استقروا في قطر التي كانت تحت حكم ال مسلم وهناك اكتسب العتوب مهارات الصيد والغوص علا اللءلء مكتسبين خبراتهم البحرية من المناطق المحيطة بهم كعمان والبحرين الا ان استقرارهم في قطر لم يطل نتيجة لخلاف بين العتوب و ال مسلم فهاجر بعض العتوب بعد ذلك الا البحرين فيما استقر ما يقارب من سفينة عند مدخل شط العرب حيث اجبرته السلطات العثمانية علا الرحيل فسكنوا القرين
# ****************************************************************************************************
# تشارك بعض التعديلات مثل تلك التي تءثر علا بي بي وشبه دي كيه ان ايه في السرطانة حرشفية الخلايا وبعض الانواع الاخرا الاكثر شيوعا من السرطانات الرءوية غير صغيرة الخلايا والسرطانة الغدية الرءوية
# تشارك بعض التعديلات مثل تلك التي تءثر علا تي بي وسيه دي كيه ان ايه في السرطانة حرشفية الخلايا وبعض الانواع الاخرا الاكثر شيوعا من السرطانات الرءوية غير صغيرة الخلايا والسرطانة الغدية الرءوية
# ****************************************************************************************************
# في يوليو اختير راميريز للمشاركة مع فريق الاوروغواي في منافسات كرة القدم في الالعاب الاولمبية الصيفية واحرز هدفا في مباراة احماءية امام بنما في الخامس عشر من يوليو
# في يوليو اختير راميريز للمشاركة مع فريق الاوروغواي في منافسات كرة القدم في الالعاب الاولمبية الصيفية واحرز هدفا في مباراة احماءية امام بنما في الخامس عشر من يوليو
# ****************************************************************************************************
# تبدا مقدمات ارقام الهواتف في كندا والولايات المتحدة الامريكية وبعض بلدان الكاريبي بالرقم بينما المناطق المحلية في هذه البلدان تدار بواسطة خطة ترقيم امريكا الشمالية حيث يوجد لكل منطقة وولاية مفتاح خاص بها يتم اضافته بعد مقدمة البلد مباشرة
# تبدا مقدمات ارقام الهواتف في كندا والولايات المتحدة الامريكية وبعض بلدان الكاريبي بالرقم بينما المناطق المحلية في هذه البلدان تدار بواسطة خطة ترقيم امريكا الشمالية حيث يوجد لكل منطقة وولاية مفتاح خاص بها يتم اضافته بعد مقدمة البلد مباشرة
# /home/majed_alshaibani/Experiments/dotless-arabic/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:70: FutureWarning: Importing `word_error_rate` from `torchmetrics.functional` was deprecated and will be removed in 2.0. Import `word_error_rate` from `torchmetrics.text` instead.
#   _future_warning(
# /home/majed_alshaibani/Experiments/dotless-arabic/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:70: FutureWarning: Importing `char_error_rate` from `torchmetrics.functional` was deprecated and will be removed in 2.0. Import `char_error_rate` from `torchmetrics.text` instead.
#   _future_warning(
# ****************************************************************************************************
# كما يعتبر اتحاد موردي المياه والطاقة الالماني وهو مجموعة ضغط نشطة في مجال ادارة الطاقة ان الانتقال الطاقي امرا لا رجعة فيه ففي ابريل صرح هيلديغارد مولر المديرة الرءيسية للاتحاد لصحيفة فدي باكريشين الاسبوعية قاءلة لم يعد الامر يتعلق بمعرفته فقط بل كيفية تنفيذ الانتقال ودعت في الوقت نفسه الا توجيه افضل من قبل المسءولين السياسيين للتجول في سوق الطاقة واخيرا وضع المواطنون انفسهم كجهات نشطة في العملية يمتلكون من الطاقة الانتاجية للطاقة المتجددة من خلال التعاون
# كما يعتبر اتحاد موردي المياه والطاقة الالماني وهو مجموعة ضغط نشطة في مجال ادارة الطاقة ان الانتقال الطاقي امرا لا رجعة فيه ففي ابريل صرح هيلديغارد مولر المديرة الرءيسية للاتحاد لصحيفة فدي ناكريشتن الاسبوعية قاءلة لم يعد الامر يتعلق بمعرفته فقط بل كيفية تنفيذ الانتقال ودعت في الوقت نفسه الا توجيه افضل من قبل المسءولين السياسيين للتحول في سوق الطاقة واخيرا وضع المواطنون انفسهم كجهات نشطة في العملية يمتلكون من الطاقة الانتاجية للطاقة المتجددة من خلال التعاون
# ****************************************************************************************************
# يبلغ عدد سكان قرية الفنجرة حوالي نسمة وهذا العدد في تزايد مضطرد نتيجة للتزايد الطبيعي في اعداد سكانها اضافة الا الهجرة الوافدة حيث يقصدها الباحثون عن السكن لقربها من اللاذقية وانخفاض اسعار العقارات فيها بالمقارنة مع مدينة اللاذقية
# يبلغ عدد سكان قرية القنجرة حوالي نسمة وهذا العدد في تزايد مضطرد نتيجة للتزايد الطبيعي في اعداد سكانها اضافة الا الهجرة الوافدة حيث يقصدها الباحثون عن السكن لقربها من اللاذقية وانخفاض اسعار العقارات فيها بالمقارنة مع مدينة اللاذقية
# ****************************************************************************************************
# كتب دومينيك سالر ويورغن زيمرز انه بسبب الافتقار الا الشتات العالمي ودولة الامة كان ينظر للاشوريين علا انهم اكثر عرضة للخطر واقل تهديدا مما ادا الا ابادتهم بشكل اقل منهجية
# كتب دومينيك شالر ويورغن زيمرر انه بسبب الافتقار الا الشتات العالمي ودولة الامة كان يتظر للاشوريين علا انهم اكثر عرضة للخطر واقل تهديدا مما ادا الا ابادتهم بشكل اقل منهجية
# ****************************************************************************************************
# في بعض الاحيان فان رقم كولن العام يتم تعريفه ليكون رقم علي صيغة جيث واذا كان هناك عددا اوليا يمكن كتابته علي تلك الصيغة فانه سوف يدعي مباشرة رقم كولن العام في بعض الاحيان يتم تسمية رقم وودال برقم كولن من الدرجة الثانية
# في بعض الاحيان فان رقم كولن العام يتم تعريفه ليكون رقم علي صيغة حيث واذا كان هناك عددا اوليا يمكن كتابته علي تلك الصيعة فانه سوف يدعي مباشرة رقم كولن العام في بعض الاحيان يتم تسمية رقم وودال برقم كولن من الدرجة الثانية
# ****************************************************************************************************
# لم تكتشف كتابات كثيرة عن المكاربة واغلب نصوصهم المكتشفة بهذا النمط واستنبط الباحثون ان ليدعءيل دارج ابن اسمه سمح علي ننوف وكان الحاكم الثالث في قاءمة حكام شبا كان يحكم بالتشارك مع عدد من الكهنة كذلك هم يدعءيل بين وببع امر وهم اخوته ويظهر ان عددا من زعماء القباءل تبرع لتشييد عدد من الاصلاحات علا المعبد وكان زعيما من قبيلة قديمة اسمها دي بيرن وزعيم قبيلة اخرا اسمها ذو رحصن وهذه النون التي تزين اخر الاسماء هي اداة التعريف المطلق في لغة العرب الجنوبيين القديمة وسبقت اسماء زعماء تلك القباءل لفظة مودد وتعني رجلا يتودد للحاكم وقريب منه واكتشف نص اخر يتحدث عن تبرع رجل من قبيلة اسمها ذو لحد ببناء مردع سور لمدينة اس
# لم تكتشف كتابات كثيرة عن المكاربة واغلب نصوصهم المكتشفة بهذا النمط واستنبط الباحثون ان ليدعءيل ذارح ابن اسمه سمح علي ينوف وكان الحاكم الثالث في قاءمة حكام سبا كان يحكم بالتشارك مع عدد من الكهنة كذلك هم يدعءيل بين ويثع امر وهم اخوته ويظهر ان عددا من زعماء القباءل تبرع لتشييد عدد من الاصلاحات علا المعبد وكان زعيما من قبيلة قديمة اسمها ذي يبرن وزعيم قبيلة اخرا اسمها ذو رحضن وهذه النون التي تزين اخر الاسماء هي اداة التعريف المطلق في لغة العرب الجنوبيين القديمة وسبقت اسماء زعماء تلك القباءل لفظة مودد وتعني رجلا يتودد للحاكم وقريب منه واكتشف نص اخر يتحدث عن تبرع رجل من قبيلة اسمها ذو لحد ببناء مردع سور لمدينة اسم
# ****************************************************************************************************
# في عام في الفترة من مارس وشاركت فرنسا وتشارك حاليا في تنفيذ منطقة حظر الطيران فوق شمال ليبيا خلال الحرب الاهلية الليبية من اجل منع القوات الموالية معمر القذافي من القيام بهجمات جوية علا مكافحة القذافي القوات
# في عام في الفترة من مارس وشاركت فرنسا وتشارك حاليا في تنفيذ منطقة حظر الطيران فوق شمال ليبيا خلال الحرب الاهلية الليبية من اجل منع القوات الموالية معمر القذافي من القيام بهجمات جوية علا مكافحة القذافي القوات
# ****************************************************************************************************
# علا سبيل المثال في عام عندما ضرب اعصار ميتش الساحل الشمالي لهندوراس كانت المجتمعات الغاريفونا بين الاكثر تضررا ولكن بسبب تاريخ من الفساد وانعدام المسءولية للحكومة في هندوراس وقد تم تجاهل هذه المجتمعات
# علا سبيل المثال في عام عندما ضرب اعصار ميتش الساحل الشمالي لهندوراس كانت المجتمعات الغاريفونا بين الاكثر تضررا ولكن بسبب تاريخ من الفساد وانعدام المسءولية للحكومة في هندوراس وقد تم تجاهل هذه المجتمعات
# ****************************************************************************************************
# منذ عقود طويلة وقرية المرابي لا يعرف الا بصيد السمك فالبحر هو مصدر رزق اثناءها اما الزراعة والرعي فهي قليلة بحكم ان اغلب الاراضي رملية لا تزرع الا في موسم الامطار الزراعة الموسمية
# منذ عقود طويلة وقرية المرابي لا تعرف الا بصيد السمك فالبحر هو مصدر رزق ابناءها اما الزراعة والرعي فهي قليلة بحكم ان اغلب الاراضي رملية لا تزرع الا في موسم الامطار الزراعة الموسمية
# ****************************************************************************************************
# وستساهم زاوية سيدي داود من جديد في تفعيل دور ونشاط الزوايا والمدارس القرانية المتواجدة بولاية بومرداس ومتابعة النشاط المسجدي من اجل الحفاظ علا هوية الشعب الجزاءري وعدم زعزعته عن دينه واصالته في ظل ما يتعرض له العالم الاسلامي من هجمات دينية وذلك من خلال ما تقدمه من نشاطات دينية كحفظ وتدريس القران والاحاديث النبوية الشريفة ودروس في الوعظ ولارشاد ونبذ الخلافات واصلاح ذات البين
# وستساهم زاوية سيدي داود من جديد في تفعيل دور ونشاط الزوايا والمدارس القرانية المتواجدة بولاية بومرداس ومتابعة النشاط المسجدي من اجل الحفاظ علا هوية الشعب الجزاءري وعدم زعزعته عن دينه واصالته في ظل ما يتعرض له العالم الاسلامي من هجمات دينية وذلك من خلال ما تقدمه من نشاطات دينية كحفظ وتدريس القران والاحاديث النبوية الشريفة ودروس في الوعظ ولارشاد ونبذ الخلافات واصلاح ذات البين
# ****************************************************************************************************
# كانت المدية قبل عام تتبع قضاء مدينة الرملة التي اصبحت الان جزء من الاراضي المحتلة عام واصبحت المدية بعد ذلك تتبع قضاء مدينة رام الله بعد ان تم مصادرة معظم اراضيها
# كانت المدية قبل عام تتبع قضاء مدينة الرملة التي اصبحت الان جزء من الاراضي المحتلة عام واصبحت المدية بعد ذلك تتبع قضاء مدينة رام الله بعد ان تم مصادرة معظم اراضيها
# ****************************************************************************************************
# من التلاءمات الشاءعة لهذه الالية ما يحدث في حالة الجراثيم داخل الخلوية والاورام حيث يحدث تنظيم ادنا مزمن لجزيءات المعقد التوافق النسيجي من النمط الاول مما يجعل الخلية لا تتاثر بالمناعة المتواسطة بالخلايا التاءية
# من التلاءمات الشاءعة لهذه الالية ما يحدث في حالة الجراثيم داخل الخلوية والاورام حيث يحدث تنظيم ادنا مزمن لجزيءات المعقد التوافق النسيجي من النمط الاول مما يجعل الخلية لا تتاثر بالمناعة المتواسطة بالخلايا التاءية
# ****************************************************************************************************
# وفيما انقرضت سلالة ماينهاردينغر في عام جرا التنازل عن تيرول لال هاسبيرغ الذين حكموا المنطقة لخمسة القرون ونصف القرن الثالثة وتخلل ذلك فترة وجيزة من سيطرة البافاريين في بداية التسعينيات في خلال الحروب النابليونية
# وقتما انقرضت سلالة ماينهاردينغر في عام جرا التنازل عن تيرول لال هاسبيرغ الذين حكموا المنطقة لخمسة القرون ونصف القرن التالية وتخلل ذلك فترة وجيزة من سيطرة البافاريين في بداية التسعينيات في خلال الحروب النابليونية
# ****************************************************************************************************
# يستخدم المكشاف ثلاثة انواع من العدادات للتعرف علا الميونات وقياس كمية حركتها غرفة السلكصمام الازاحة وغرفة المهبط الشريحي وغرفة اللوحة المقاومة
# يستخدم المكشاف ثلاثة انواع من العدادات للتعرف علا الميونات وقياس كمية حركتها غرفة السلكصمام الازاحة وغرفة المهبط الشريحي وغرفة اللوحة المقاومة
# ****************************************************************************************************
# و للكنيسة رواق من قسمين خارجي جنوبي و يتكون الرواق من قسمين خارجي وداخلي و يظهر ذلك قواعد الاعمدة وعددها خمس قواعد وتستخدم الاعمدة لتوزيع نقل السقف الكنيسة الضخم والجملوني الشكل وللكنيسة رواق شمالي و قد اعتمد في بناءه مبدا التناظر وقد احتوا علا ست قواعد للاعمدة وينتهي الرواق بمدخل يفضي الا مجاز خارجي وهو مشابه للرواق الجنوبي والمحار الخارجي هو عبارة عن مدخل يتخذ شكل رواق مستعرض يمتد امام الواجهة الغربية للكنيسة
# و للكنيسة رواق من قسمين خارجي جنوبي و يتكون الرواق من قسمين خارجي وداخلي و يظهر ذلك قواعد الاعمدة وعددها خمس قواعد وتستخدم الاعمدة لتوزيع ثقل السقف الكنيسة الضخم والجملوني الشكل وللكنيسة رواق شمالي و قد اعتمد في بناءه مبدا التناظر وقد احتوا علا ست قواعد للاعمدة وينتهي الرواق بمدخل يفضي الا مجاز خارجي وهو مشابه للرواق الجنوبي والمجاز الخارجي هو عبارة عن مدخل يتخذ شكل رواق مستعرض يمتد امام الواجهة الغربية للكنيسة
# ****************************************************************************************************
# اقيمت هذه المسابقة علا عدة فترات من ايام المهرجان علا ان تتحصل علا القعود من يستطيع طرحه خلال اقل من دقيقة ويتاهل للجاءزة الكبرا من يستطيع طرحه في اول ثانية من الوقت وقد تاهل افضل ثلاثة حققوا اقل توقيت وهم عماش مناحي المصارير الدوسري وطرح القعود في باتنة وسليمان محمد النفيعي وطرح القعود في ثانية فيما اذا سالم صالح ال جابر المهمة في باتنة
# اقيمت هذه المسابقة علا عدة فترات من ايام المهرجان علا ان يتحصل علا القعود من يستطيع طرحه خلال اقل من دقيقة ويتاهل للجاءزة الكبرا من يستطيع طرحه في اول ثانية من الوقت وقد تاهل افضل ثلاثة حققوا اقل توقيت وهم عماش مناحي المصارير الدوسري وطرح القعود في ثانية وسليمان محمد النفيعي وطرح القعود في ثانية فيما ادا سالم صالح ال جابر المهمة في ثانية
# ****************************************************************************************************
# عملت في تلفزيون البحرين حيث قدمت عام برنامج الحال مع لجين بعد ذلك شاركت في تقديم برنامج يا هلا علا قناة روتانا خليجية شكل انتقالها لتقديم برنامج صباح الخير يا عرب علا ام بي سي نقلة نوعية في طبيعة البرامج التي قدمتها قدمت امسيات شعرية في مهرجانات عدة كمهرجان الدوحة الثقافي عام ومهرجان هجن الرءاسة في ابوظبي حيث كرمت في كلا المهرجانين مارست مهنة الصحافة الورقية من خلال صفحة ثابتة مثيرة للجدل في احدا المطبوعات السعودية اختيرت من قبل دار الصدا الاماراتية كاكثر شخصية مءثرة في الشتات لعام وكافضل مذيعة لعام في مجلة زهرة الخليج
# عملت في تلفزيون البحرين حيث قدمت عام برنامج الحال مع لجين بعد ذلك شاركت في تقديم برنامج يا هلا علا قناة روتانا خليجية شكل انتقالها لتقديم برنامج صباح الخير يا عرب علا ام بي سي نقلة نوعية في طبيعة البرامج التي قدمتها قدمت امسيات شعرية في مهرجانات عدة كمهرجان الدوحة الثقافي عام ومهرجان هجن الرءاسة في ابوظبي حيث كرمت في كلا المهرجانين مارست مهنة الصحافة الورقية من خلال صفحة ثابتة مثيرة للجدل في احدا المطبوعات السعودية اختيرت من قبل دار الصدا الاماراتية كاكثر شخصية مءثرة في الشباب لعام وكافضل مذيعة لعام في مجلة زهرة الخليج
# ****************************************************************************************************
# لم تشهد الحملة سوا معركة رءيسية واحدة في نيوتاون بسبب اخلاء القباءل قبل القوة العسكرية الكبيرة علا طول نهر شيمونغ في غرب نيويورك الا انها الحقت اضرارا بالغة باقتصاد الايراكوس من خلال حرق محاصيلهم وقراهم وممتلكاتهم وبالتالي دمرت البنية التحتية
# لم تشهد الحملة سوا معركة رءيسية واحدة في نيوتاون بسبب اجلاء القباءل قبل القوة العسكرية الكبيرة علا طول نهر شيمونغ في غرب نيويورك الا انها الحقت اضرارا بالغة باقتصاد الايراكوس من خلال حرق محاصيلهم وقراهم وممتلكاتهم وبالتالي دمرت البنية التحتية
# ****************************************************************************************************
# تحكا قصة قمر الزمان عن ملك من قديم الزمان وقد تقدم به العمر ولم ينجب الا ان تزوج من اميرة بلاد صديقه وانجبا قمر الزمان الذي لم يكن له مثيل في جماله ولما كبر علمه ابوه العلوم والاداب حتا صار لايماثله احد في علمه وجماله وذكاءه ثم اراد ابوه ان يزوجه فابا لانه كان يعتقد ان جميع النساء خاءنات الا ان رايه بنت ملك الجن التي كان يراهن حتي علا انه لا يوجد مثيل لابنه ملك الصين في جمالها اما ابنة ملك الجن فانها كانت تعتقد ان قمر الزمان هو الاجمل فاتفقا علا ان ينقل ابنه ملك الصين الا سرير قمر الزمان وتوقظوكل منهم علا الاخر ليعرفوا من يقتين بالاخر فيكون هو الاقل جمالا
# تحكا قصه قمر الزمان عن ملك من قديم الزمان وقد تقدم به العمر ولم ينجب الا ان تزوج من اميرة بلاد صديقه وانجبا قمر الزمان الذي لم يكن له مثيل في جماله ولما كبر علمه ابوه العلوم والاداب حتا صار لايماثله احد في علمه وجماله وذكاءه ثم اراد ابوه ان يزوجه فابا لانه كان يعتقد ان جميع النساء خاءنات الا ان راته بنت ملك الجن التي كان يراهن جني علا انه لا يوجد مثيل لابنة ملك الصين في جمالها اما ابنة ملك الجن فانها كانت تعتقد ان قمر الزمان هو الاجمل فاتفقا علا ان تنقل ابنة ملك الصين الا سرير قمر الزمان ويوقظوكل منهم علا الاخر ليعرفوا من يفتتن بالاخر فيكون هو الاقل جمالا
# ****************************************************************************************************
# بدات حياتها الفنية بعام كمطربة بفرقة اسكندر فرح وتالفت كثيرا فيما بعد في عقد الثلاثينات القرن العشرين وهي الاخت الكبرا للفنانة نجمة ابراهيم تزوجت وعاشت هي وزوجها في الاسكندرية حتا قيام دولة الصهاينة فهاجرت اليها من اشهر اغانيها قصيدة افدنة ان حفظ الهوا شاركت في الثلاثينات في الكثير من المسرحيات التي عرضت في ذلك الزمان مثل مسرحية شهداء الغرام وغادة الكاميليا وصحبة العاوية واخذت نوتردام والجبابرة والسلطان عبدالحميد واولاد الفقراء ويوم القيامة واهل الكهف
# بدات حياتها الفنية بعام كمطربة بفرقة اسكندر فرح وتالقت كثيرا فيما بعد في عقد الثلاثينات القرن العشرين وهي الاخت الكبرا للفنانة نجمة ابراهيم تزوجت وعاشت هي وزوجها في الاسكندرية حتا قيام دولة الصهاينة فهاجرت اليها من اشهر اغانيها قصيدة افديه ان حفظ الهوا شاركت في الثلاثينات في الكثير من المسرحيات التي عرضت في ذلك الزمان مثل مسرحية شهداء الغرام وغادة الكاميليا وضحية الغاوية واحدب نوتردام والجبابرة والسلطان عبدالحميد واولاد الفقراء ويوم القيامة واهل الكهف
# ****************************************************************************************************
# كما يجدر بالذكر ان قدرة الاجنة علا لام خروجهم دون ندوب تعتمد علا حجم الجرح وعلا العمر ايضا حيث لوحظ تشكيل نديه عند حدوث جرح ما بعد عمر حملي معين غالبا اسبوعا لدا الانسان وبينما ظلت الية التءام الجروح دون تشكيل ندوب عند الاجنة مجهولة فقد اظهرت الابحاث انها قد تكون بسبب التفاعلات المعقدة بين مكونات مصفوفة خارج الخلية والاستجابة الالتهابية والوسطاء الخلوتين وعوامل نمو محددة
# كما يجدر بالذكر ان قدرة الاجنة علا لام جروحهم دون ندوب تعتمد علا حجم الجرح وعلا العمر ايضا حيث لوحظ تشكيل ندبة عند حدوث جرح ما بعد عمر حملي معين غالبا اسبوعا لدا الانسان وبينما ظلت الية التءام الجروح دون تشكيل ندوب عند الاجنة مجهولة فقد اظهرت الابحاث انها قد تكون بسبب التفاعلات المعقدة بين مكونات مصفوفة خارج الخلية والاستجابة الالتهابية والوسطاء الخلويين وعوامل نمو محددة
# ****************************************************************************************************
# وفي حين ان بيانات الانتحار والانتحار لمهن الجيش والسلامة العامة ليست شاملة فان هذه المهن ليست استثناءات للروابط الراسخة بين مختلف اضطرابات الصحة العقلية وزيادة خطر الوفاة عن طريق الانتحار
# وفي حين ان بيانات الانتحار والانتحار لمهن الجيش والسلامة العامة ليست شاملة فان هذه المهن ليست استثناءات للروابط الراسخة بين مختلف اضطرابات الصحة العقلية وزيادة خطر الوفاة عن طريق الانتحار
# ****************************************************************************************************
# يعتبر اتباع الكنيسة الاسقفية الطاءفة المسيحية الاكثر تعلما وثراء في الولايات المتحدة ولدا الاسقفيون اعلا نسبة من الحاصلين علا شهادة جامعية وحوالي منهم لديهم شهادات دراسات عليا وما يزالون يشكلون ايضا جزء من النخبة البرية والمتعلمة والسياسية في الولايات المتحدة
# يعتبر اتباع الكنيسة الاسقفية الطاءفة المسيحية الاكثر تعلما وثراء في الولايات المتحدة ولدا الاسقفيون اعلا نسبة من الحاصلين علا شهادة جامعية وحوالي منهم لديهم شهادات دراسات عليا وما يزالون يشكلون ايضا جزء من النخبة الثرية والمتعلمة والسياسية في الولايات المتحدة
# ****************************************************************************************************
# بينما انهوا علا صدارة مجموعتهم في مراحل البلياردو كاس العالم خرجت استراليا بعد خسارتها مع انجلترا في ربع النهاءي مرة اخرا الا حد كبير بسبب براعة جوني ويلكنسون في تسجيل الاهداف
# بينما انهوا علا صدارة مجموعتهم في مراحل البلياردو كاس العالم خرجت استراليا بعد خسارتها مع انجلترا في ربع النهاءي مرة اخرا الا حد كبير بسبب براعة جوني ويلكنسون في تسجيل الاهداف
# ****************************************************************************************************
# اثناء الاعداد للثورة ظهرت علا مسرح الاحداث شخصية اثرت بشدة علا مجرا الاحداث وهو المختار بن ابي عبيد الثقفي وكان عند ابن الزبير ولكنه ما لبث ان اختلف معه ثم خرج من مكة متوجها للكوفة وبدا يدعو لخلافة محمد بن الحنفية ولقبه بالمهدي وادا ذلك ليفرق صف انصار الحسين وصاروا فرقتين جمهورهم مع سليمان بن صرد للاخذ بثار الحسين والباقي مع المختار وهذا الاختلاف وصلت اخباره لوالي الكوفة من قبل ابن الزبير فحذرهم من محاولة الخروج علا الامويين لكن هذا التحذير ادا لاستعجال خروج سليمان ومن معه لقتال اهل الشام
# اثناء الاعداد للثورة ظهرت علا مسرح الاحداث شخصية اثرت بشدة علا مجرا الاحداث وهو المختار بن ابي عبيد الثقفي وكان عند ابن الزبير ولكنه ما لبث ان اختلف معه ثم خرج من مكة متوجها للكوفة وبدا يدعو لخلافة محمد بن الحنفية ولقبه بالمهدي وادا ذلك لتفرق صف انصار الحسين وصاروا فرقتين جمهورهم مع سليمان بن صرد للاخذ بثار الحسين والباقي مع المختار وهذا الاختلاف وصلت اخباره لوالي الكوفة من قبل ابن الزبير فحذرهم من محاولة الخروج علا الامويين لكن هذا التحذير ادا لاستعجال خروج سليمان ومن معه لقتال اهل الشام
# ****************************************************************************************************
# لعب سابقا مع بريستون لايونز من الا ثم في موسم ثم مع ميلبورن بايتس من الا وفي موسم مع باتاهايكي اليوناني ثم مع كوينزلاند روز حتا الانتقال الا اديلايد يونايتد في فبراير للعب في دوري ابطال اسيا ابتداء من مارس
# لعب سابقا مع بريستون لايونز من الا ثم في موسم ثم مع ميلبورن نايتس من الا وفي موسم مع باناهايكي اليوناني ثم مع كوينزلاند رور حتا الانتقال الا اديلايد يونايتد في فبراير للعب في دوري ابطال اسيا ابتداء من مارس
# ****************************************************************************************************
# يتضمن الشكل الحالي للبطولة سبعة فرق تتنافس علا اللقب في ملاعب داخل الدولة المضيفة علا مدا اسبوعين تقريبا اسماء الفاءزين في النسخة تلك السنة من اسيا دوري ابطال اسيا افريقيا دوري ابطال افريقيا امريكا الشمالية دوري ابطال الكونكاكاف امريكا الجنوبية كاس ليبرتادوريس اوقيانوسيا دوري ابطال اوقيانوسيا واوروبا دوري ابطال اوروبا جنبا الا جنب مع البطل الوطني في الدولة المضيفة والمشاركة في مرحلة خروج المغلوب علا التوالي
# يتضمن الشكل الحالي للبطولة سبعة فرق تتنافس علا اللقب في ملاعب داخل الدولة المضيفة علا مدا اسبوعين تقريبا اسماء الفاءزين في النسخة تلك السنة من اسيا دوري ابطال اسيا افريقيا دوري ابطال افريقيا امريكا الشمالية دوري ابطال الكونكاكاف امريكا الجنوبية كاس ليبرتادوريس اوقيانوسيا دوري ابطال اوقيانوسيا واوروبا دوري ابطال اوروبا جنبا الا جنب مع البطل الوطني في الدولة المضيفة والمشاركة في مرحلة خروج المغلوب علا التوالي
# ****************************************************************************************************
# قدم الاغاني السيدة فيروز نصري شمس الدين هدا حداد محمد مرعي جوزيف ناصيف ايلي شويري جورجيت صانع ملحم بركات انطوان او مروان محفوظ نوال الكك صلاح تيزاني ابو سليم عبد الله حمصي اسعد محمود مبسوط فهمان محمد السراج والفرقة الشعبية اللبنانية
# قدم الاغاني السيدة فيروز نصري شمس الدين هدا حداد محمد مرعي جوزيف ناصيف ايلي شويري جورجيت صايغ ملحم بركات انطوان او مروان محفوظ نوال الكك صلاح تيزاني ابو سليم عبد الله حمصي اسعد محمود مبسوط فهمان محمد السراج والفرقة الشعبية اللبنانية
# ****************************************************************************************************
# وعندما قررت جامعة الموصل سنة اصدار اول موسوعة حضارية عن الموصل وقع الاختيار عليه ليكون رءيسا لتحريرها وقد عملت معه في عضوية هيءة التحرير ومسءولية قسم التاريخ الحديث والمعاصر وانجزت الهيءة الموسوعة بخمسة مجلدات سنة
# وعندما قررت جامعة الموصل سنة اصدار اول موسوعة حضارية عن الموصل وقع الاختيار عليه ليكون رءيسا لتحريرها وقد عملت معه في عضوية هيءة التحرير ومسءولية قسم التاريخ الحديث والمعاصر وانجزت الهيءة الموسوعة بخمسة مجلدات سنة
# ****************************************************************************************************
# استخدم كل من جينتيركو وشابيرو ونادي نص سجل الكونغرس لتوثيق الاختلاف في انماط الكلام عند الجمهوريين والديموقراطيين كمقياس للاستقطاب ووجدوا في دراساتهم زيادة كبيرة في انماط الخطب التي تستخدم للاستقطاب بدءا من عام
# استخدم كل من جينتنزكو وشابيرو وتادي نص سجل الكونغرس لتوثيق الاختلاف في انماط الكلام عند الجمهوريين والديموقراطيين كمقياس للاستقطاب ووجدوا في دراساتهم زيادة كبيرة في انماط الخطب التي تستخدم للاستقطاب بدءا من عام
# ****************************************************************************************************
# بعد استقلال الهند في عام اصبحت المدينة عاصمة ولاية مدراس والتي غير اسمها الا تاميل نادو في عام شكلت الاحتجاجات العنيفة في صد القرص الاجباري للغة الهندية ودعم اللغة الانجليزية تحولا كبيرا في سياسة المدينة وسياسة البلد باكملها حيث بقيت اللغة الانجليزية لغة رسمية بجانب اللغة الهندية
# بعد استقلال الهند في عام اصبحت المدينة عاصمة ولاية مدراس والتي غير اسمها الا تاميل نادو في عام شكلت الاحتجاجات العنيفة في ضد الفرض الاجباري للغة الهندية ودعم اللغة الانجليزية تحولا كبيرا في سياسة المدينة وسياسة البلد باكملها حيث بقيت اللغة الانجليزية لغة رسمية بجانب اللغة الهندية
# ****************************************************************************************************
# تزرع علا اراضيها الخصبة المعروفة باسم سهل عجة الحبوب والقطاني والخضراوات بالاضافة الا الاشجار المثمرة كالزيتون واللوز والمشمش اضافة الا قطاع زيت الزيتون من حيث زراعة الزيتون وعصره في معاصر حديثة داخل البلدة
# تزرع علا اراضيها الخصبة المعروفة باسم سهل عجة الحبوب والقطاني والخضراوات بالاضافة الا الاشجار المثمرة كالزيتون واللوز والمشمش اضافة الا قطاع زيت الزيتون من حيث زراعة الزيتون وعصره في معاصر حديثه داخل البلدة
# ****************************************************************************************************
# ولم تصمد الامثلة الهامة عن المعاهدات غير المتكافءة علا الصين امام الحرب العالمية الثانية بينما ظلت المعاهدات غير المتكافءة التي تتعلق بهونغ كونغ في مكانها حتا تسليم هونغ كونغ عام وفي عام اعادت الصين التاكيد علا معاهدة ايجون من اجل تحسين العلاقات الصينية الروسية
# ولم تصمد الامثلة الهامة عن المعاهدات غير المتكافءة علا الصين امام الحرب العالمية الثانية بينما ظلت المعاهدات غير المتكافءة التي تتعلق بهونغ كونغ في مكانها حتا تسليم هونغ كونغ عام وفي عام اعادت الصين التاكيد علا معاهدة ايجون من اجل تحسين العلاقات الصينية الروسية
# ****************************************************************************************************
# بين الثامنة عشر والرابعة والعشرين عاما ونسبة كانت واقعة في الفءة العمرية ما بين الخامسة والعشرين والرابعة والاربعين عاما ونسبة كانت ما بين الخامسة والاربعين والرابعة والستين ونسبة
# بين الثامنة عشر والرابعة والعشرين عاما ونسبة كانت واقعة في الفءة العمرية ما بين الخامسة والعشرين والرابعة والاربعين عاما ونسبة كانت ما بين الخامسة والاربعين والرابعة والستين ونسبة
# ****************************************************************************************************
# قتل وفقا لايان هانكوك جميع الرومن تقريبا في كرواتيا واستونيا وليتوانيا ولوكسمبورغ وهولندا ويقدر رودولف روميل اعداد وفيات الرومن بنحو شخص في اوروبا نحو شخص في رومانيا تحت سيطرة يون انتونيسكو ونحو شخص في كرواتيا التي يسيطر عليها الاوستاشا
# قتل وفقا لايان هانكوك جميع الرومن تقريبا في كرواتيا واستونيا وليتوانيا ولوكسمبورغ وهولندا ويقدر رودولف روميل اعداد وفيات الرومن بنحو شخص في اوروبا نحو شخص في رومانيا تحت سيطرة يون انتونيسكو ونحو شخص في كرواتيا التي تسيطر عليها الاوستاشا
# ****************************************************************************************************
# و في عام صدرت الرسوم الكاريكاتيرية المسيءة لرسول الله محمد عليه الصلاة والسلام وهو ما اثار حفيظة المنتج ياسر زايد وقرر انتاج اوبريت غناءي ضخم بعنوان لا بني يهان من كلمات عبد المنعم طه والحان اشرف سالم وتوزيع يحيا الموجي و انور عمرو شارك في الاوبريت عدد كبير منهم الفنان محمود ياسين ومحمد العربي ومجد القاسم ومي كساب وحنان عطية وغيرهم
# و في عام صدرت الرسوم الكاريكاتيرية المسيءة لرسول الله محمد عليه الصلاة والسلام وهو ما اثار حفيظة المنتج ياسر زايد وقرر انتاج اوبريت غناءي ضخم بعنوان لا نبي يهان من كلمات عبد المنعم طه والحان اشرف سالم وتوزيع يحيا الموجي و انور عمرو شارك في الاوبريت عدد كبير منهم الفنان محمود ياسين ومحمد العزبي ومجد القاسم ومي كساب وحنان عطية وغيرهم
# ****************************************************************************************************
# وتعتبر بونديشيري في الاونة الاخيرة مركزا علميا في جنوب الهند فهي مقر لجامعة مركزية و كليات طبية و كليات هندسية و كليات طب اسنان وكلية قانون وكلية طب بيطري وكلية زراعة و كليات علوم وفنون و كليات علوم تطبيقية
# وتعتبر بونديشيري في الاونة الاخيرة مركزا علميا في جنوب الهند فهي مقر لجامعة مركزية و كليات طبية و كليات هندسية و كليات طب اسنان وكلية قانون وكلية طب بيطري وكلية زراعة و كليات علوم وفنون و كليات علوم تطبيقية
# ****************************************************************************************************
# ما هو خط السيطرة هل هو الخط الذي اوجدوه بالعدوان منذ بداية سبتمبر ان التقدم باربعين او ستين كيلومترا بالعدوان العسكري الصارخ وعرض الانسحاب عشرين كيلومترا شريطة ان يقوم الطرفان بذلك هو خدعة لا يمكن ان تنطلي علا اح
# ما هو خط السيطرة هل هو الخط الذي اوجدوه بالعدوان منذ بداية سبتمبر ان التقدم باربعين او ستين كيلومترا بالعدوان العسكري الصارخ وعرض الانسحاب عشرين كيلومترا شريطة ان يقوم الطرفان بذلك هو خدعة لا يمكن ان تنطلي علا احد
# ****************************************************************************************************
# وكان طاسو الذي بدا يعزف الة البيانو وهو في سنة الخامس قد نما اهتماما كبيرا في التحف الاثرية والاعمال الفنية وموسيقا عصر الباروك المقدسة ففتح عام معرض فن اسماه وتخصص بالارت نوفو وبالفن الشرقي وبدا يرسم منمنمات ويمارس فن الخط
# وكان طاسو الذي بدا بعزف الة البيانو وهو في سنه الخامس قد نما اهتماما كبيرا في التحف الاثرية والاعمال الفنية وموسيقا عصر الباروك المقدسة ففتح عام معرض فن اسماه وتخصص بالارت نوفو وبالفن الشرقي وبدا يرسم منمنمات ويمارس فن الخط
# ****************************************************************************************************
# وفي الوقت الذي رفض فيه فيشر المشاركة في التصفيات ما بين المناطقية المءهلة لبطولة العالم في استغل الوقت لاجراء جولة في الولايات المتحدة وكندا استمرت من شباط حتا ايار
# وفي الوقت الذي رفض فيه فيشر المشاركة في التصفيات ما بين المناطقية المءهلة لبطولة العالم في استغل الوقت لاجراء جولة في الولايات المتحدة وكندا استمرت من شباط حتا ايار
# ****************************************************************************************************
# قرية الكفل الحالية فيقال انها في موقع مدينة بلاسكر التي انتباها احد الملوك اليرنيين في اواءل النصرانية سنة بعد المسيح لاستجلاب التجارات والبضاءع من اقاصي الهند والشام واسيا الصغرا
# قرية الكفل الحالية فيقال انها في موقع مدينة بلاشكر التي ابتناها احد الملوك البرثيين في اواءل النصرانية سنة بعد المسيح لاستجلاب التجارات والبضاءع من اقاصي الهند والشام واسيا الصغرا
# ****************************************************************************************************
# بدا مسيرته الكروية مع نادي بوافيشتا في عام ولعب معهم حتا عام وشارك معهم في مباراة وسجل هدف وفي عام انتقل الا نادي بنفيكا ولعب معهم حتا عام وشارك معهم في مباراة وسجل هدف وفي عام انتقل الا نادي فيورنتينا الايطالي ولعب معهم حتا عام وشارك معهم في مباراة وسجل هدف وفي عام عاد الا نادي بنفيكا البرتغالي ولعب لهم الا وشارك معهم في مباراة وسجل هدف وفي صيف انتقل الا نادي سبورتينغ براغا البرتغالي ولعب لهم لمدة موسم واحد شارك خلالها في مباراة وسجل اهداف وفي انتقل الا نادي بلاكبيرن روفرز لعب لهم موسم واحد شارك خلالها في مباراة وسجل اهداف وفي اعلن اعتزاله كرة القدم بشكل نهاءي بعمر عاما
# بدا مسيرته الكروية مع نادي بوافيستا في عام ولعب معهم حتا عام وشارك معهم في مباراة وسجل هدف وفي عام انتقل الا نادي بنفيكا ولعب معهم حتا عام وشارك معهم في مباراة وسجل هدف وفي عام انتقل الا نادي فيورنتينا الايطالي ولعب معهم حتا عام وشارك معهم في مباراة وسجل هدف وفي عام عاد الا نادي بنفيكا البرتغالي ولعب لهم الا وشارك معهم في مباراة وسجل هدف وفي صيف انتقل الا نادي سبورتينغ براغا البرتغالي ولعب لهم لمدة موسم واحد شارك خلالها في مباراة وسجل اهداف وفي انتقل الا نادي بلاكبيرن روفرز لعب لهم موسم واحد شارك خلالها في مباراة وسجل اهداف وفي اعلن اعتزاله كرة القدم بشكل نهاءي بعمر عاما
# ****************************************************************************************************
# الدوق كورو وجوبريال والدوق الثاني نييلان يمثلان نموذج الطمع والجشع وهذا النموذج لا يفهم العواطف ولا المشاعر الانسانية ولا القيم النبيلة ولا يمتزج معها فهو واياها في خصام داءم يظهر السمو والنبل والكرامة وهو منها بريء هذا النموذج لم يستطع فهم عواطف المراة واحاسيسها ومشاعرها الرقيقة وهي الصق الناس به اعمته عن ذلك نوازع النفس البشرية المغرمة بالجاه والتقرب من الحاكم والمنصب وحب الظهور باي ثمن كان حيا علا حساب الشرف والعرض لذلك سعت امراتا الدوق كورو وجوبريال والدوق الثاني للبحث عن حصن دافء جنون بحثا عن الامان في غمرة الحياة الضبابية فوجدنا ضالتها عند قاءد الجيش الذي تزوج الوسطا سر ا ومارس الرذيلة مع ال
# الدوق كورو وجونريال والدوق الباني نبيلان يمثلان نموذج الطمع والجشع وهذا النموذج لا يفهم العواطف ولا المشاعر الانسانية ولا القيم النبيلة ولا يمتزج معها فهو واياها في خصام داءم يظهر السمو والنبل والكرامة وهو منها بريء هذا النموذج لم يستطع فهم عواطف المراة واحاسيسها ومشاعرها الرقيقة وهي الصق الناس به اعمته عن ذلك نوازع النفس البشرية المغرمة بالجاه والتقرب من الحاكم والمنصب وحب الظهور باي ثمن كان حتا علا حساب الشرف والعرض لذلك سعت امراتا الدوق كورو وجونريال والدوق الباني للبحث عن حضن دافء حنون بحثا عن الامان في غمرة الحياة الضبابية فوجدتا ضالتها عند قاءد الجيش الذي تزوج الوسطا سر ا ومارس الرذيلة مع الك
# ****************************************************************************************************
# وقد قدم غريغوري بيرلمان في عام دليلا علا هذا التخمين استنادا الا العمل الذي قام به ريتشارد هاميلتون تم الانتهاء من المراجعة في اغسطس وتم اختيار بيرلمان لتلقي ميدالية فيلدز لحله لكنه رفض الجاءزة
# وقد قدم غريغوري بيرلمان في عام دليلا علا هذا التخمين استنادا الا العمل الذي قام به ريتشارد هاميلتون تم الانتهاء من المراجعة في اغسطس وتم اختيار بيرلمان لتلقي ميدالية فيلدز لحله لكنه رفض الجاءزة
# ****************************************************************************************************
# وبالرغم من ان نويعات الببور المختلفة تمتلك خصاءص تميزها عن بعضها البعض الا ان ذكر الببر يبقا يزن بين و كيلوغرام بينما تزن الانثا بين و كيلوغرام ويبلغ متوسط طول الذكور بين
# وبالرغم من ان نويعات الببور المختلفة تمتلك خصاءص تميزها عن بعضها البعض الا ان ذكر الببر يبقا يزن بين و كيلوغرام بينما تزن الانثا بين و كيلوغرام ويبلغ متوسط طول الذكور بين
# ****************************************************************************************************
# ايزواي اي سي جاي بي سي دبليو جي شبكات الاستشعار هي مجموعة عمل معيارية من اللجنة الفنية المشتركة المنظمة الدولية للمعايير واللجنة الكهروتقنية الدولية والتي تطور وتسهل المعايير في مجال شبكات الاستشعار الامانة الدولية ل ايزواي اي سي جاي بي سي دبليو جي هي الوكالة الكورية للتكنولوجيا والمعايير ومقرها جمهورية كوريا
# ايزواي اي سي جاي تي سي دبليو جي شبكات الاستشعار هي مجموعة عمل معيارية من اللجنة الفنية المشتركة المنظمة الدولية للمعايير واللجنة الكهروتقنية الدولية والتي تطور وتسهل المعايير في مجال شبكات الاستشعار الامانة الدولية ل ايزواي اي سي جاي تي سي دبليو جي هي الوكالة الكورية للتكنولوجيا والمعايير ومقرها جمهورية كوريا
# ****************************************************************************************************
# وفي تصريح اخر لوكالة انباء البحرين بان التحضيرات لاصدار الكتاب امتدت لعامين من العمل المتواصل نظرا الا التدقيق اللغوي باللغتين العربية والاجنبية كذلك بالنسبة الا الصور واختيار الالوان والوصفات الغذاءية وذلك حتا يرا الكتاب النور بالشكل المرضي للجميع ولمحبي الطبخ
# وفي تصريح اخر لوكالة انباء البحرين بان التحضيرات لاصدار الكتاب امتدت لعامين من العمل المتواصل نظرا الا التدقيق اللغوي باللغتين العربية والاجنبية كذلك بالنسبة الا الصور واختيار الالوان والوصفات الغذاءية وذلك حتا يرا الكتاب النور بالشكل المرضي للجميع ولمحبي الطبخ
# ****************************************************************************************************
# علا الرغم من ان الماء يمكن ان يدخل البدلة الا ان البدلة تمنع فقدان الحرارة المفرط لان القليل من الماء الساخن داخل البدلة يتسرب منها ليحل محله الماء البارد وهي عملية يشار اليها باسم التنظيف
# علا الرغم من ان الماء يمكن ان يدخل البدلة الا ان البدلة تمنع فقدان الحرارة المفرط لان القليل من الماء الساخن داخل البدلة يتسرب منها ليحل محله الماء البارد وهي عملية يشار اليها باسم التنظيف
# ****************************************************************************************************
# وصفت مجلة فوربس الامريكية هذا التجاهل بانه امر صادم بينما وصفته مجلة ذا اتلانتيك بانه مخيب للامال ولكنه بالكاد صادم اخذه بعين الاعتبار كون فيلم قصير الاجل فيلم مستقل بميزانية صغيرة
# وصفت مجلة فوربس الامريكية هذا التجاهل بانه امر صادم بينما وصفته مجلة ذا اتلانتيك بانه مخيب للامال ولكنه بالكاد صادم اخذة بعين الاعتبار كون فيلم قصير الاجل فيلم مستقل بميزانية صغيرة
# ****************************************************************************************************
# وايد ثورة رشيد عالي الكيلاني في ايار فلما اجهضت خرج لاجءا الا ايران في ايار مع قادة حكومة الدفاع الوطني ووزراءها والقي القبض عليه في مدينة طهران فنقل الا الاهواز ومنها الا ورودنسة ثم اعيد للعراق فاعتقل في بغداد والبصرة والعمارة والسليمانية والموصل وافرج عنه في نهاية الحرب العالمية الثانية بعد ان قضا في المعتقلات مدة اربعة سنوات وبضعة اشهر
# وايد ثورة رشيد عالي الكيلاني في ايار فلما اجهضت خرج لاجءا الا ايران في ايار مع قادة حكومة الدفاع الوطني ووزراءها والقي القبض عليه في مدينة طهران فنقل الا الاهواز ومنها الا وروديسة ثم اعيد للعراق فاعتقل في بغداد والبصرة والعمارة والسليمانية والموصل وافرج عنه في نهاية الحرب العالمية الثانية بعد ان قضا في المعتقلات مدة اربعة سنوات وبضعة اشهر
# ****************************************************************************************************
# ومع تقدم العلم وتطوير اجهزة تحليل الضوء وزيادة تباينها فقد تبين ان كل خط من تلك الخطوط اما ان يتكون من خطين ويعزا هذا الانفطار الا البناء الدقيق في الذرة حيث ان الالكترون له عزم مغزلي وقد يكون اتجاهه علوي او قد يكون اتجاهه سفلي
# ومع تقدم العلم وتطوير اجهزة تحليل الضوء وزيادة تباينها فقد تبين ان كل خط من تلك الخطوط اما ان يتكون من خطين ويعزا هذا الانفطار الا البناء الدقيق في الذرة حيث ان الالكترون له عزم مغزلي وقد يكون اتجاهه علوي او قد يكون اتجاهة سفلي
# ****************************************************************************************************
# بالنسبة لتاثيرات رقم خمسة الذي يقفز عبر الزمان والمكان اراد بوريل ان يجعل التاثيرات تبدو عضوية وسيولة تميل كم من الوقت والعالم تنحني حوله عندما تقفز ومدا السرعة التي يجب ان تكون
# بالنسبة لتاثيرات رقم خمسة الذي يقفز عبر الزمان والمكان اراد بوريل ان يجعل التاثيرات تبدو عضوية وسيولة تمثل كم من الوقت والعالم ينحني حوله عندما يقفز ومدا السرعة التي يجب ان تكون
# ****************************************************************************************************
# اتجه احمد بن طولون في اواخر ايامه الا تحسين الاجواء بينه وبين الموفق فابدا الاخير استعداده نظرا لان الخلاف لم يصب في المصلحة العامة للمسلمين وادا الا اضعاف مصر والعراق علا حد سواء واشترط احمد بن طولون ان يكون تكريم الخليفة العباسي ورد اعتباره اليه ببدا اساسيا في الصلح فقبل الموفق وبادر بتكريم الخليفة ورد اليه اعتباره واطلقه من محبسه
# اتجه احمد بن طولون في اواخر ايامه الا تحسين الاجواء بينه وبين الموفق فابدا الاخير استعداده نظرا لان الخلاف لم يصب في المصلحة العامة للمسلمين وادا الا اضعاف مصر والعراق علا حد سواء واشترط احمد بن طولون ان يكون تكريم الخليفة العباسي ورد اعتباره اليه بندا اساسيا في الصلح فقبل الموفق وبادر بتكريم الخليفة ورد اليه اعتباره واطلقه من محبسه
# ****************************************************************************************************
# كان يوحنا هونياد قد اخبر برانكويتش بانه احضر من رجاله وانه بانتظار تعزيزات اضافية في طريقها اليه وانه اي برانكويتش بسلاح فرسانه الخفيفة هو الحليف الوحيد الضروري لجعل هذا النصر حاسما وفي المقابل كان برانكويتش حذرا جدا من المشاركة مع التحالف الصليبي لان العثمانيون كانوا قد اعادوا له عرشه وملكه منذ اربع سنوات فقط من خلال معاهدة سلام ادرنة سكدين عام م بعد ان سلبها منه العثمانيون قبلها بفتوحات واسعة النطاق لكل املاكه واراضيه في بلاد الصرب بلا استثناء وكان برانكويتش مدركا تماما للقوة العسكرية العثمانية المهولة راغبا في الحفاظ علا عرشه ومتحملا لمسءءلية سيادة المجر وتبعيته لسيادة العثمانيين في نفس الو
# كان يوحنا هونياد قد اخبر برانكويتش بانه احضر من رجاله وانه بانتظار تعزيزات اضافية في طريقها اليه وانه اي برانكويتش بسلاح فرسانه الخفيفة هو الحليف الوحيد الضروري لجعل هذا النصر حاسما وفي المقابل كان برانكويتش حذرا جدا من المشاركة مع التحالف الصليبي لان العثمانيون كانوا قد اعادوا له عرشه وملكه منذ اربع سنوات فقط من خلال معاهدة سلام ادرنة سكدين عام م بعد ان سلبها منه العثمانيون قبلها بفتوحات واسعة النطاق لكل املاكه واراضيه في بلاد الصرب بلا استثناء وكان برانكويتش مدركا تماما للقوة العسكرية العثمانية المهولة راغبا في الحفاظ علا عرشه ومتحملا لمسءءلية سيادة المجر وتبعيته لسيادة العثمانيين في نفس الوق
# ****************************************************************************************************
# لم تسلم سكاي وورث من بعض الاخفاقات فبعد نموها السريع بين اعوام و اضطرت الشركة ان تغلق وحدة اجهزة صغيرة واضطرت ان تتبع شركة هواتف محمولة حديثة النسا وتنبع من اسهمها للداءنين باسعار رمزية وعانت لفترة من انخفاض طفيف في نسبة المبيعات
# لم تسلم سكاي وورث من بعض الاخفاقات فبعد نموها السريع بين اعوام و اضطرت الشركة ان تغلق وحدة اجهزة صغيرة واضطرت ان تبيع شركة هواتف محمولة حديثة النشا وتبيع من اسهمها للداءنين باسعار رمزية وعانت لفترة من انخفاض طفيف في نسبة المبيعات
# ****************************************************************************************************
# فعاد الا مسقط راسه مشهد واثناء حضوره هناك قام بالتدريس الدروس المختلفة مثل الفقه تاريخ الفقه تاريخ الحديث شرح الحديث تفسير القران تاريخ التفسير علم الكلام الفلسفة وغيرها في كلية الدراسات الاسلامية في جامعة مشه
# فعاد الا مسقط راسه مشهد واثناء حضوره هناك قام بالتدريس الدروس المختلفة مثل الفقه تاريخ الفقه تاريخ الحديث شرح الحديث تفسير القران تاريخ التفسير علم الكلام الفلسفة وغيرها في كلية الدراسات الاسلامية في جامعة مشهد
# ****************************************************************************************************
# تسكن قروش الملاك علا اعماق بين وحتا م وفي القيعان الطينية او الرملية حيث يمكنها التخفي منتظرة قدوم الغذاء هذه المناطق تعد مثالية لها لوجود كل من الحرارة المثالية والاوكسجين والملوحة ودرجات العمق
# تسكن قروش الملاك علا اعماق بين وحتا م وفي القيعان الطينية او الرملية حيث يمكنها التخفي منتظرة قدوم الغذاء هذه المناطق تعد مثالية لها لوجود كل من الحرارة المثالية والاوكسجين والملوحة ودرجات العمق
# ****************************************************************************************************
# اغسطس انضمت الناشطة الشابة سناء سيف عاما للعدد المتزايد من السجناء السياسيين الذين كانوا قد بداوا اضرابا عن الطعام من خلف الاسوار للاحتجاج علا اوضاعهم في المعتقل شتاء بدات الاضراب بعد حضور جنازة والدها المحامي الحقوقي المعروف احمد سيف الاسلام والذي وافته المنية يوم اغسطس
# اغسطس انضمت الناشطة الشابة سناء سيف عاما للعدد المتزايد من السجناء السياسيين الذين كانوا قد بداوا اضرابا عن الطعام من خلف الاسوار للاحتجاج علا اوضاعهم في المعتقل سناء بدات الاضراب بعد حضور جنازة والدها المحامي الحقوقي المعروف احمد سيف الاسلام والذي وافته المنية يوم اغسطس
# ****************************************************************************************************
# ...
# ****************************************************************************************************
# دغرفوش وهي مدينة تقع في غرب السويد في محافظة اوربرو في اقليم فيرملاند بالقرب من مدينة كارلس كوغا ويبلغ عدد سكان مدينة ديغافوس حوالي نسمة حسب احصاءيات سنة
# دغرفوش وهي مدينة تقع في غرب السويد في محافظة اوربرو في اقليم فيرملاند بالقرب من مدينة كارلس كوغا ويبلغ عدد سكان مدينة ديغافوش حوالي نسمة حسب احصاءيات سنة
# ****************************************************************************************************
# قبل قضية هارلو ضد فيتزجيرالد اقتصرت الحصانة التي منحتها المحكمة العليا الامريكية للمسءولين الحكوميين علا الحالات التي ظن المسءول بدافع حسن النية ان سلوكه كان قانونيا و يكون فيها السلوك معقولا من الناحية الموضوعية
# قبل قضية هارلو ضد فيتزجيرالد اقتصرت الحصانة التي منحتها المحكمة العليا الامريكية للمسءولين الحكوميين علا الحالات التي ظن المسءول بدافع حسن النية ان سلوكه كان قانونيا و يكون فيها السلوك معقولا من الناحية الموضوعية
# ****************************************************************************************************
# لادراج نص برمجي متسق بخط ثابت العرض بامكانك اما ان تحيط الكود المضمن باشارات اقتباس خلفية او ان تبدا السطور العديدة من الكود علا الاقل مع اربع مسافات بادءة
# لادراج نص برمجي منسق بخط ثابت العرض بامكانك اما ان تحيط الكود المضمن باشارات اقتباس خلفية او ان تبدا السطور العديدة من الكود علا الاقل مع اربع مسافات بادءة
# ****************************************************************************************************
# تسما الشعوذة ايضا بالسحر الاسود ويمكن اعتباره فرعا من فروع السحر الذي يستند علا استحضار مايسما بالقوا الشريرة او قوا الظلام التي تطلب مساعدتها عادة لاتزال الدمار او الحاق الاذا او تحقيق مكاسب شخصية
# تسما الشعوذة ايضا بالسحر الاسود ويمكن اعتباره فرعا من فروع السحر الذي يستند علا استحضار مايسما بالقوا الشريرة او قوا الظلام التي يطلب مساعدتها عادة لانزال الدمار او الحاق الاذا او تحقيق مكاسب شخصية
# ****************************************************************************************************
# المحطة الحرارية او محطة توليد الطاقة الكهرباءية في الزارة هي محطة توليد طاقة كهرباءية تقع في محافظة حماة بالقرب من قرية الزارة وتبعد كم غرب الطريق العام الواصل بين مدينتي حمص و حماة علا الضفة الشمالية لبحيرة سد الرستن
# المحطة الحرارية او محطة توليد الطاقة الكهرباءية في الزارة هي محطة توليد طاقة كهرباءية تقع في محافظة حماة بالقرب من قرية الزارة وتبعد كم غرب الطريق العام الواصل بين مدينتي حمص و حماة علا الضفة الشمالية لبحيرة سد الرستن
# ****************************************************************************************************
# اما العرب الاشراف فقد اختطوا في بداية امرهم قصورا في الطريقية جنوب الغيشة وعرب عين ماضي القصر الاحمر بناه المناصير والقصر الابيض بناه النفاني وكانوا يسكنون معا ولم يفترقا ابدا
# اما العرب الاشراف فقد اختطوا في بداية امرهم قصورا في الطريفية جنوب الغيشة وغرب عين ماضي القصر الاحمر بناه المناصير والقصر الابيض بناه النقابي وكانوا يسكنون معا ولم يفترقا ابدا
# ****************************************************************************************************
# لقد ادا اهمال تطبيق مبادء العوامل البشرية في تصميم الادوات واماكن العمل الا الكثير من الاصابات في الاجهزة الداعمة لاجسام العاملين بدءا من الصدمات والجروح وانتهاء بالام اسفل الظهر الحادة بتكاليف تتعدا مليار دولار في الولايات المتحدة الامريكية
# لقد ادا اهمال تطبيق مبادء العوامل البشرية في تصميم الادوات واماكن العمل الا الكثير من الاصابات في الاجهزة الداعمة لاجسام العاملين بدءا من الصدمات والجروح وانتهاء بالام اسفل الظهر الحادة بتكاليف تتعدا مليار دولار في الولايات المتحدة الامريكية
# ****************************************************************************************************
# وعضو مءسس في جمعية طيبة التعاونية للاسكان والتي قامت بانشاء مبنا وعمارة سكنية بمساحة بناء اولية مقدارها الف متر مربع علا قطعة ارض مساحتها دونما في منطقة السرو من ضواحي مدينة السلط قرب عمان العاصمة الاردنية وشغل امينا للصندوق ورءيسا للجمعية عدة دورات
# وعضو مءسس في جمعية طيبة التعاونية للاسكان والتي قامت بانشاء مبنا وعمارة سكنية بمساحة بناء اولية مقدارها الف متر مربع علا قطعة ارض مساحتها دونما في منطقة السرو من ضواحي مدينة السلط قرب عمان العاصمة الاردنية وشغل امينا للصندوق ورءيسا للجمعية عدة دورات
# ****************************************************************************************************
# هذه تقنية حصل علا براءة اختراعها ماكس فليتشير عام حيث يستخدم رساموا الكربون افلام حقيقية من ممثلين حقيقيين ليقوموا بتمثيل الدور المطلوب كاملا ثم يستخدموا الروتوسكوب ليعيدوا رسم هذا المشهد من الفيلم الحقيقي بطريقة كرتونية كما في فيلم سيد الخواتم عام وفيلم اسكانز داركلي عام وفيلم هيفي ميتال عام والعديد من الافلام الاخرا
# هذه تقنية حصل علا براءة اختراعها ماكس فليتشير عام حيث يستخدم رساموا الكرتون افلام حقيقية من ممثلين حقيقيين ليقوموا بتمثيل الدور المطلوب كاملا ثم يستخدموا الروتوسكوب ليعيدوا رسم هذا المشهد من الفيلم الحقيقي بطريقة كرتونية كما في فيلم سيد الخواتم عام وفيلم اسكانر داركلي عام وفيلم هيفي ميتال عام والعديد من الافلام الاخرا
# ****************************************************************************************************
# بعد تحويل الا في يونيو كان هو المعهد الوحيد غير التابع ل الذي قتل يسما الان الطلاب المءهلين في مختلف برامج البكالوريوس والدرجات المزدوجة
# بعد تحويل الا في يونيو كان هو المعهد الوحيد غير التابع ل الذي قبل يسما الان الطلاب المءهلين في مختلف برامج البكالوريوس والدرجات المزدوجة
# ****************************************************************************************************
# منح موقع الطماطم الفاسدة الفيلم تقييما مقداره بناءا علا اراء ناقدا سينماءيا وكتب الاجماع النقدي للموقع ماجي كيو ما زالت تنتظر فيلم الحركة الذي يستحقها حقا ولكن حتا ذلك الحين تظهر الحمايةكضربة موفقة للمشاه
# منح موقع الطماطم الفاسدة الفيلم تقييما مقداره بناءا علا اراء ناقدا سينماءيا وكتب الاجماع النقدي للموقع ماجي كيو ما زالت تنتظر فيلم الحركة الذي يستحقها حقا ولكن حتا ذلك الحين يظهر الحمايةكضربة موفقة للمشاهد
# ****************************************************************************************************
# وكذلك كان الخليفة الواثق الذي كان يغني له اسحاق وابراهيم الموصلي وهما من اشهر الموسيقيين في العصر الاموي وعبد الرحمن بن الحكم الذي ذاع في عهده صيت الفتا زرياب وهو تلميذ اسحق الموصلي وغيرهم كثيرون ممن اشتهروا بغناء وتلحين القصاءد الدينية والاناشيد واشتهر المنشدين بشكل مميز في حلب علا وجه الخصوص ومقدمة كتاب مءتمر الموسيقا العربية للدكتور محمود احمد الحفني
# وكذلك كان الخليفة الواثق الذي كان يغني له اسحاق وابراهيم الموصلي وهما من اشهر الموسيقيين في العصر الاموي وعبد الرحمن بن الحكم الذي ذاع في عهده صيت الفتا رزياب وهو تلميذ اسحق الموصلي وغيرهم كثيرون ممن اشتهروا بغناء وتلحين القصاءد الدينية والاناشيد واشتهر المنشدين بشكل مميز في حلب علا وجه الخصوص ومقدمة كتاب مءتمر الموسيقا العربية للدكتور محمود احمد الحفني
# ****************************************************************************************************
# من بين سلالات الدنا المتقدري الاكثر شيوعا في البلاد سلالة التي يبدو انها مقتصرة علا سكان ايران والقوقاز في حين ان المجموعة الفرعية شاءعة في منطقة الشرق الادنا باكملها
# من بين سلالات الدنا المتقدري الاكثر شيوعا في البلاد سلالة التي يبدو انها مقتصرة علا سكان ايران والقوقاز في حين ان المجموعة الفرعية شاءعة في منطقة الشرق الادنا باكملها
# ****************************************************************************************************
# كما فاز بستة جواءز في مهرجان جواءز فيلم فير من بينها جواءز النقاد الثلاثة جاءزة افضل فيلم وجاءزة افضل ممثل التي حصل عليها باجباي وجاءزة افضل ممثلة التي حصلت عليها شاه
# كما فاز بستة جواءز في مهرجان جواءز فيلم فير من بينها جواءز النقاد الثلاثة جاءزة افضل فيلم وجاءزة افضل ممثل التي حصل عليها باجباي وجاءزة افضل ممثلة التي حصلت عليها شاه
# ****************************************************************************************************
# الفارو بيليغرين غيسيندو الشهير باسم الفارو غيسيندو مايو في مونتيفيديو الاوروغواي يناير في سانتا كلارا ديل اوليمار الاوروغواي لاعب كرة قدم اوروغواياني كان يجيد اللعب في خط الوسط
# الفارو بيليغرين غيستيدو الشهير باسم الفارو غيستيدو مايو في مونتيفيديو الاوروغواي يناير في سانتا كلارا ديل اوليمار الاوروغواي لاعب كرة قدم اوروغواياني كان يجيد اللعب في خط الوسط
# ****************************************************************************************************
# مشروع فيدورا هو مشروع مستقل لتنسيق تطوير فيدورا لينكس وهو نظام تشغيل قاءم علا لينكس ويعمل برءية عالم يستفيد فيه الجميع من البرامج المجانية والمفتوحة المصدر التي تم انشاءها من قبل مجتمعات مرخية ومنفتحة تضم الجميع
# مشروع فيدورا هو مشروع مستقل لتنسيق تطوير فيدورا لينكس وهو نظام تشغيل قاءم علا لينكس ويعمل برءية عالم يستفيد فيه الجميع من البرامج المجانية والمفتوحة المصدر التي تم انشاءها من قبل مجتمعات مرحبة ومنفتحة تضم الجميع
# ****************************************************************************************************
# تعني برقة كلمة برقة في اللغة العربية التلون وقد ذكر ياقوت الحموي حوالي مكان في الجزيرة العربية بهذا الاسم وتعني هنا المكان الذي يحتوي علا الحجارة الملونة وفي فلسطين هناك اكثر من مكان بهذا الاسم ف برقة نابلس وبرقة رام الله
# تعني برقة كلمة برقة في اللغة العربية التلون وقد ذكر ياقوت الحموي حوالي مكان في الجزيرة العربية بهذا الاسم وتعني هنا المكان الذي يحتوي علا الحجارة الملونة وفي فلسطين هناك اكثر من مكان بهذا الاسم ف برقة نابلس وبرقة رام الله
# ****************************************************************************************************
# تشكك اسامة غريب من صحيفة المصري اليوم حيث كتب طبقا للحكاية فان وردة عندما سءلت عن البداية قالت انها تعلقت ببليغ منذ اول مرة سمعت فيها اغنية تخونوه التي لحنها لعبد الحليم حافظ وكانت وردة في ذلك الوقت ابنة سبعة عشر عاما ومازالت تعيش بفرنسا ولم تحترف الغناء بعد ورغم ذلك فقد حدثت نفسها بانها سوف تتزوج هذا الملحن ذات يوم وتابع انا لا انفي قصة الحب بين وردة وبليغ لكنها حال حدوثها لابد ان تكون حدثت بعد اللقاء والعمل المشترك في اواءل الستينيات اما محاولة اقناعنا بان لحن اغنية يخونوه هو السبب فهو كلام لا يبطلا علا طفل خصوصا ان الطلاق قد وقع بينهما بعد سنوات قلاءل من الارتباط وقد يصح القول ان سءال يخونوهيصلح في تفسير ال
# يشكك اسامة غريب من صحيفة المصري اليوم حيث كتب طبقا للحكاية فان وردة عندما سءلت عن البداية قالت انها تعلقت ببليغ منذ اول مرة سمعت فيها اغنية تخونوه التي لحنها لعبد الحليم حافظ وكانت وردة في ذلك الوقت ابنة سبعة عشر عاما ومازالت تعيش بفرنسا ولم تحترف الغناء بعد ورغم ذلك فقد حدثت نفسها بانها سوف تتزوج هذا الملحن ذات يوم وتابع انا لا انفي قصة الحب بين وردة وبليغ لكنها حال حدوثها لابد ان تكون حدثت بعد اللقاء والعمل المشترك في اواءل الستينيات اما محاولة اقناعنا بان لحن اغنية تخونوه هو السبب فهو كلام لا ينطلا علا طفل خصوصا ان الطلاق قد وقع بينهما بعد سنوات قلاءل من الارتباط وقد يصح القول ان سءال تخونوهيصلح في تفسير الط
# ****************************************************************************************************
# تم ايقاف اف ام باونز واميغا سي دي بالفعل كان جاغوار واكس لا يزالان في السوق ولكن محللي الصناعة اعتبروا قضية خاسرة اثبت نيو جيو سي دي انه تجذب السوق المتخصصة فقط وكان محللو الصناعة قد قرروا بالفعل ان ايل بانداي بيت ان الذي لم يتم اطلاقه بعد كان مكلفا للغاية لاحداث اي تاثير في السوق
# تم ايقاف اف ام تاونز واميغا سي دي بالفعل كان جاغوار واكس لا يزالان في السوق ولكن محللي الصناعة اعتبروا قضية خاسرة اثبت نيو جيو سي دي انه يجذب السوق المتخصصة فقط وكان محللو الصناعة قد قرروا بالفعل ان ابل بانداي بيب ان الذي لم يتم اطلاقه بعد كان مكلفا للغاية لاحداث اي تاثير في السوق
# ****************************************************************************************************
# علاوة علا ذلك فان المعرفة بان مثل هذه العمليات يجري تنفيذها عززت بشكل كبير من الروح المعنوية لافراد الطاقم الجوي القتالي الذين ليسوا يواجهون رد الفعل الغذاءي المتوقع للعدو فقط ولكن ايضا مع احتمال حدوث خلل في الطاءرات اثناء الرحلات الجوية الطويلة فوق الماء
# علاوة علا ذلك فان المعرفة بان مثل هذه العمليات يجري تنفيذها عززت بشكل كبير من الروح المعنوية لافراد الطاقم الجوي القتالي الذين ليسوا يواجهون رد الفعل العداءي المتوقع للعدو فقط ولكن ايضا مع احتمال حدوث خلل في الطاءرات اثناء الرحلات الجوية الطويلة فوق الماء
# ****************************************************************************************************
# كان احد الاهداف العلمية لرحلة ابولو تاريخ الزمن الذي تعود اليه المواد التي تاثرت باصطدامات الاحواض القمرية العاءدة الا الفترة النكتارية لكن مع ذلك فان عمر حوض الرحيق بكتارس غامض ومنهم نوعا ما فاكثرية نتاءج الحسابات تحدد ارقاما تبدا من زمن قبل
# كان احد الاهداف العلمية لرحلة ابولو تاريخ الزمن الذي تعود اليه المواد التي تاثرت باصطدامات الاحواض القمرية العاءدة الا الفترة النكتارية لكن مع ذلك فان عمر حوض الرحيق نكتارس عامض ومبهم نوعا ما فاكثرية نتاءج الحسابات تحدد ارقاما تبدا من زمن قبل
# ****************************************************************************************************
# عبر ال غريكو اسلوبه الا حد كبير علا عكس الفنانين الكريتيين الاخرين الذين انتقلوا الا البندقية وسعا الا تمييز نفسه عن طريق اختراع تفسيرات جديدة وغير عادية للمواضيع الدينية التقليدية
# غير ال غريكو اسلوبه الا حد كبير علا عكس الفنانين الكريتيين الاخرين الذين انتقلوا الا البندقية وسعا الا تمييز نفسه عن طريق اختراع تفسيرات جديدة وغير عادية للمواضيع الدينية التقليدية
# ****************************************************************************************************
# حيث اسس بداءع الضبطان الشيخ حميد الضباطي من قبيلة مطير وبعد وفاته عام ه تولا الامارة ابنه خلف بن حميد حتا عام ه ومن ثم تولا ابنه سعود الامارة ولا يزال حتا الان
# حيث اسس بداءع الضبطان الشيخ حميد الضباطي من قبيلة مطير وبعد وفاته عام ه تولا الامارة ابنه خلف بن حميد حتا عام ه ومن ثم تولا ابنه سعود الامارة ولا يزال حتا الان
# ****************************************************************************************************
# وما ان مات سيدي الشيخ سنة ه م حتا اصبحت القصور تشيد علا شكل حصون متوزعة علا اربعة القصر العربي قصر اولاد سيد الحاج بحوض قصر الرحامنة وقصر اولاد سيد الحاج احمد وبمركز اولاد ومحيي ومجدوبي ومريدي الطريقة الشيخية بالابيض سيدي الشيخ بها
# وما ان مات سيدي الشيخ سنة ه م حتا اصبحت القصور تشيد علا شكل حصون متوزعة علا اربعة القصر الغربي قصر اولاد سيد الحاج بحوص قصر الرحامنة وقصر اولاد سيد الحاج احمد وتمركز اولاد ومحبي ومجدوبي ومريدي الطريقة الشيخية بالابيض سيدي الشيخ بها
# ****************************************************************************************************
# في عام اعلن عن حاجة الجيش العراقي لضباط جدد فدخل عبد الكريم قاسم الكلية العسكرية وتخرج منها بتفوق في يوم نيسان ابريل عام برتبة ملازم ثان وتدرج في رتبته الا ان وصل الا رتبة زعيم ركن اصبحت الان عميد ركن وكان اخر مركز شغله في المءسسة العسكرية هو امر اللواء التاسع عشر ولقد شارك في العديد من الحروب والحركات مثل حرب فلسطين وحركات الفرات الاولا كذلك شارك في حركة مايس التحررية وشارك في العديد من الدورات العسكرية وحصل علا العديد من الاوسمة وفي التقارير التي وردت عنه انه ضابط ركن جيد خلوق جدا وسيكون من ضباط الجيش القديرين
# في عام اعلن عن حاجة الجيش العراقي لضباط جدد فدخل عبد الكريم قاسم الكلية العسكرية وتخرج منها بتفوق في يوم نيسان ابريل عام برتبة ملازم ثان وتدرج في رتبته الا ان وصل الا رتبة زعيم ركن اصبحت الان عميد ركن وكان اخر مركز شغله في المءسسة العسكرية هو امر اللواء التاسع عشر ولقد شارك في العديد من الحروب والحركات مثل حرب فلسطين وحركات الفرات الاولا كذلك شارك في حركة مايس التحررية وشارك في العديد من الدورات العسكرية وحصل علا العديد من الاوسمة وفي التقارير التي وردت عنه انه ضابط ركن جيد خلوق جدا وسيكون من ضباط الجيش القديرين
# ****************************************************************************************************
# ويعد قياس العلاقات الاجتماعية البحثي بحثا اجراءيا مع مجموعات استكشاف الشبكات الاجتماعية العاطفية للعلاقات باستخدام معايير محددة مثل من في هذه المجموعة يرغب في الجلوس بجانبه في العمل من في هذه المجموعة تذهب اليه للحصول علا النصيحة بشان اي مشكلة في العمل من في هذه المجموعة نرا انه يوفر قيادة مرضية في المشاريع قيد التنفيذ احيانا يهتم قياس العلاقات الاجتماعية البحثي والذي يسما باكتشافات الشبكة بالانماط المتصلة في المجموعات الصغيرة الافراد والمجموعات الصغيرة والمجموعات الاكبر من الناس مثل المنظمات والاحياء
# ويعد قياس العلاقات الاجتماعية البحثي بحثا اجراءيا مع مجموعات استكشاف الشبكات الاجتماعية العاطفية للعلاقات باستخدام معايير محددة مثل من في هذه المجموعة ترغب في الجلوس بجانبه في العمل من في هذه المجموعة تذهب اليه للحصول علا النصيحة بشان اي مشكلة في العمل من في هذه المجموعة ترا انه يوفر قيادة مرضية في المشاريع قيد التنفيذ احيانا يهتم قياس العلاقات الاجتماعية البحثي والذي يسما باكتشافات الشبكة بالانماط المتصلة في المجموعات الصغيرة الافراد والمجموعات الصغيرة والمجموعات الاكبر من الناس مثل المنظمات والاحياء

# %%
avg_wer = sum(wers)/len(wers)
avg_cer = sum(cers)/len(cers)
print('avg_wer, avg_cer:',avg_wer,avg_cer)
# Out:
# avg_wer, avg_cer: tensor(0.0316) tensor(0.0072)

# %% [markdown]
# text metrics with vowel words loader

# %%
labels_with_dots = list()
for batch in testloader_with_dots:
  _,batch_labels = batch
  batch_labels = batch_labels.view(-1,seq_len)
  for sample_labels in batch_labels:
    labels_with_dots.append(sample_labels)
print('len lables with vowel words of the test set:',len(labels_with_dots))

# %%
wers,cers = list(),list()
for sample_preds,sample_labels in tqdm(zip(predictions,labels_with_dots),total=len(predictions)):
  wer,cer,ver = calculate_text_metrics(
      predictions=sample_preds.tolist(),
      labels=sample_labels.tolist(),
      target_tokenizer=target_tokenizer,
    )
  wers.append(wer)
  cers.append(cer)

# %%
avg_wer = sum(wers)/len(wers)
avg_cer = sum(cers)/len(cers)
print('avg_wer, avg_cer, avg_ver:',avg_wer,avg_cer)

# %% [markdown]
# test on the best model according to the validation loss

# %%
# model = LitBiLSTMModel.load_from_checkpoint(
#     trainer.checkpoint_callback.best_model_path,
#     vocab_size=source_tokenizer.vocab_size,
#     output_size=target_tokenizer.vocab_size,
#   )
# model

# %%
# trainer.test(model,testloader)

# %%
# model_predictions = trainer.predict(model,testloader)

# %%
# predictions = list()
# labels = list()
# for (batch_predictions,batch_labels) in model_predictions:
#   batch_predictions = batch_predictions.view(-1,seq_len)
#   batch_labels = batch_labels.view(-1,seq_len)
#   for sample_predictions,sample_labels in zip(batch_predictions,batch_labels):
#     predictions.append(sample_predictions)
#     labels.append(sample_labels)
# print('len predictions and lables of the test set:',len(predictions),len(labels))

# %%
# wers,cers,vers = list(),list(),list()
# for sample_preds,sample_labels in tqdm(zip(predictions,labels),total=len(predictions)):
#   wer,cer,ver = calculate_text_metrics(
#       predictions=sample_preds.tolist(),
#       labels=sample_labels.tolist(),
#       target_tokenizer=target_tokenizer
#     )
#   wers.append(wer)
#   cers.append(cer)
#   vers.append(ver)

# %%
# avg_wer = sum(wers)/len(wers)
# avg_cer = sum(cers)/len(cers)
# avg_ver = sum(vers)/len(vers)
# print('avg_wer, avg_cer, avg_ver:',avg_wer,avg_cer,avg_ver)

# %% [markdown]
# text metrics with vowel words

# %%
# labels_with_vowel_words = list()
# for batch in testloader_with_vowel_words:
#   _,batch_labels = batch
#   batch_labels = batch_labels.view(-1,seq_len)
#   for sample_labels in batch_labels:
#     labels_with_vowel_words.append(sample_labels)
# print('len lables with vowel words of the test set:',len(labels_with_vowel_words))

# %%
# wers,cers,vers = list(),list(),list()
# for sample_preds,sample_labels in tqdm(zip(predictions,labels_with_vowel_words),total=len(predictions)):
#   wer,cer,ver = calculate_text_metrics(
#       predictions=sample_preds.tolist(),
#       labels=sample_labels.tolist(),
#       target_tokenizer=target_tokenizer,
#     )
#   wers.append(wer)
#   cers.append(cer)
#   vers.append(ver)

# %%
# avg_wer = sum(wers)/len(wers)
# avg_cer = sum(cers)/len(cers)
# avg_ver = sum(vers)/len(vers)
# print('avg_wer, avg_cer, avg_ver:',avg_wer,avg_cer,avg_ver)

# %%
# for sample_preds,sample_labels in tqdm(list(zip(predictions,labels_with_vowel_words))[:100],total=100):
#   wer,cer,ver = calculate_text_metrics(
#       predictions=sample_preds.tolist(),
#       labels=sample_labels.tolist(),
#       target_tokenizer=target_tokenizer,
#       print_text=True
#     )

# %%
# from google.colab import runtime
# runtime.unassign()
